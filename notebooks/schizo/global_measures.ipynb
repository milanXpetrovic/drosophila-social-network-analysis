# %%
import os
import toml
import scipy

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from src import settings
from src.utils import fileio

CONFIG_PATH = os.path.join(settings.CONFIG_DIR, 'main.toml')
with open(CONFIG_PATH, 'r') as file:
    config = toml.load(file)  

TREATMENTS = config['TREATMENTS']

INPUT_PATH = os.path.join(settings.RESULTS_DIR, 'global_measures')
all_treatments = fileio.load_files_from_folder(INPUT_PATH)

dataframes = []
for treatment_name, treatment_path in all_treatments.items():
    treatment_name = treatment_name.replace('.csv', '')
    if treatment_name in config['TREATMENTS']:
        df = pd.read_csv(treatment_path, index_col=0)
        df['Treatment'] = treatment_name
        dataframes.append(df)

combined_data = pd.concat(dataframes)
combined_data_reset = combined_data.reset_index()

for measure_name in combined_data.columns.tolist():
    if measure_name == 'Treatment': continue
    
    treatment_sums = {}
    for treatment in TREATMENTS:
        treatment_sums[f'sum_{treatment}'] = combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]

    anova_result = scipy.stats.f_oneway(*treatment_sums.values())

    all_data = np.concatenate([*treatment_sums.values()])
    group_labels = []
    for treatment in TREATMENTS:
        group_labels.extend([treatment] * len(combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]))

    tukey_results = pairwise_tukeyhsd(all_data, group_labels)

    print('=' * 45 + measure_name + '=' * 45)

    for treatment in treatment_sums.keys():
        print(f"{treatment} mean value: {np.mean(treatment_sums[treatment])} SD value: {np.std(treatment_sums[treatment])}")

    # print(tukey_results)

    plt.figure(figsize=(6, 4))
    order = TREATMENTS
    sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', errorbar='se', order=order)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
    print('='*90)
        
    # sns.boxplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', order=order)
    # plt.xlabel('Treatment')
    # plt.xticks(rotation=45)
    # plt.ylabel(measure_name)
    # plt.title(f'Distribution of {measure_name}', fontsize=18)
    # plt.legend('')
    # plt.show() 
    # print('='*90)
# Out:
# =============================================Total nodes=============================================
# sum_CsChBB mean value: 12.0 SD value: 0.0
# sum_w1118 mean value: 11.958333333333334 SD value: 0.19982631347136331
# sum_ELAV mean value: 12.0 SD value: 0.0
# sum_SMBA mean value: 11.904761904761905 SD value: 0.42591770999995987
# sum_TMBC mean value: 12.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 12.0 SD value: 0.0
# sum_TMBCxELAV mean value: 12.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Total edges=============================================
# sum_CsChBB mean value: 132.0 SD value: 0.0
# sum_w1118 mean value: 131.08333333333334 SD value: 4.396178896369993
# sum_ELAV mean value: 131.8095238095238 SD value: 0.6632565846278153
# sum_SMBA mean value: 130.0 SD value: 8.94427190999916
# sum_TMBC mean value: 132.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 130.9 SD value: 3.3000000000000003
# sum_TMBCxELAV mean value: 132.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Average degree weight=count=============================================
# sum_CsChBB mean value: 690.25 SD value: 120.83545975140464
# sum_w1118 mean value: 651.4981060606061 SD value: 72.51800164303432
# sum_ELAV mean value: 640.3095238095239 SD value: 248.54417535935988
# sum_SMBA mean value: 851.4222222222221 SD value: 106.33604680487318
# sum_TMBC mean value: 624.5784313725491 SD value: 92.41115000856455
# sum_ELAVxSMBA mean value: 823.9333333333332 SD value: 135.44663155649164
# sum_TMBCxELAV mean value: 769.0396825396825 SD value: 168.71522690728128
# ==========================================================================================
# ==========================================================================================
# =============================================Average degree weight=duration(seconds)=============================================
# sum_CsChBB mean value: 791.3168402777778 SD value: 148.21014268397644
# sum_w1118 mean value: 667.6689288720539 SD value: 104.161860705937
# sum_ELAV mean value: 1182.994708994709 SD value: 359.59036448684077
# sum_SMBA mean value: 900.7300925925925 SD value: 125.82517167351921
# sum_TMBC mean value: 660.1919934640524 SD value: 110.22560006528248
# sum_ELAVxSMBA mean value: 990.0972222222223 SD value: 178.95653932938583
# sum_TMBCxELAV mean value: 950.4593253968253 SD value: 352.1878997971267
# ==========================================================================================
# ==========================================================================================
# =============================================Degree heterogeneity=============================================
# sum_CsChBB mean value: 0.0 SD value: 0.0
# sum_w1118 mean value: 0.0 SD value: 0.0
# sum_ELAV mean value: 0.002214839424141748 SD value: 0.009905063023254872
# sum_SMBA mean value: 0.0 SD value: 0.0
# sum_TMBC mean value: 0.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.01487603305785124 SD value: 0.044628099173553724
# sum_TMBCxELAV mean value: 0.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Degree aassortativity=============================================
# sum_CsChBB mean value: nan SD value: nan
# sum_w1118 mean value: nan SD value: nan
# sum_ELAV mean value: -0.1322210336698075 SD value: 0.0495764055706172
# sum_SMBA mean value: nan SD value: nan
# sum_TMBC mean value: nan SD value: nan
# sum_ELAVxSMBA mean value: nan SD value: nan
# sum_TMBCxELAV mean value: nan SD value: nan
# ==========================================================================================
# ==========================================================================================
# =============================================Reciprocity=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.9992673559156784 SD value: 0.002258234567151963
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.990909090909091 SD value: 0.027272727272727247
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Network density=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.9985569985569985 SD value: 0.005024671095665285
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.9916666666666666 SD value: 0.025000000000000012
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Global efficiency=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.9996392496392497 SD value: 0.0016133246590907561
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 1.0 SD value: 0.0
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Transitivity=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.998539442596495 SD value: 0.005082306064117746
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.990909090909091 SD value: 0.027272727272727247
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Number of connected components=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 1.0 SD value: 0.0
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 1.0 SD value: 0.0
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient unweighted=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.998625541125541 SD value: 0.004735348355390626
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.9954166666666666 SD value: 0.013750000000000083
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient weight=count=============================================
# sum_CsChBB mean value: 0.5768258533586947 SD value: 0.06913253459847443
# sum_w1118 mean value: 0.6178126862906065 SD value: 0.040985589543947445
# sum_ELAV mean value: 0.4755692711105586 SD value: 0.09006741250217673
# sum_SMBA mean value: 0.5749405676637709 SD value: 0.08029497611924341
# sum_TMBC mean value: 0.5582852425001467 SD value: 0.046957032278998466
# sum_ELAVxSMBA mean value: 0.5487080849558886 SD value: 0.08572332366932119
# sum_TMBCxELAV mean value: 0.606542256103507 SD value: 0.04690610885824178
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient weight=duration(seconds)=============================================
# sum_CsChBB mean value: 0.5127042359840692 SD value: 0.08487724457458376
# sum_w1118 mean value: 0.5751574888277148 SD value: 0.034804333373430876
# sum_ELAV mean value: 0.3207091713652642 SD value: 0.12297166308472138
# sum_SMBA mean value: 0.5029736300702727 SD value: 0.08736772957158277
# sum_TMBC mean value: 0.49552065078263846 SD value: 0.0794866819776245
# sum_ELAVxSMBA mean value: 0.4775129655572245 SD value: 0.09804468703449233
# sum_TMBCxELAV mean value: 0.5144447917313406 SD value: 0.08472084350638626
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality unweighted=============================================
# sum_CsChBB mean value: 0.0 SD value: 0.0
# sum_w1118 mean value: 0.0 SD value: 0.0
# sum_ELAV mean value: 0.0001443001443001381 SD value: 0.0005024671095665086
# sum_SMBA mean value: 0.0 SD value: 0.0
# sum_TMBC mean value: 0.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.0 SD value: 0.0
# sum_TMBCxELAV mean value: 0.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality weight=count=============================================
# sum_CsChBB mean value: 0.0038510101010100625 SD value: 0.003838570735747526
# sum_w1118 mean value: 0.0025673400673400207 SD value: 0.002195017644849361
# sum_ELAV mean value: 0.02875781625781621 SD value: 0.02656003281307353
# sum_SMBA mean value: 0.002964165464165424 SD value: 0.002892809033911477
# sum_TMBC mean value: 0.007575757575757519 SD value: 0.0066974522804108365
# sum_ELAVxSMBA mean value: 0.01371212121212118 SD value: 0.021708742785222893
# sum_TMBCxELAV mean value: 0.007491582491582466 SD value: 0.013026154983808347
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality weight=duration(seconds)=============================================
# sum_CsChBB mean value: 0.007954545454545424 SD value: 0.004513778518110984
# sum_w1118 mean value: 0.0048295454545454 SD value: 0.003518261125660215
# sum_ELAV mean value: 0.040079365079365034 SD value: 0.031206678627440605
# sum_SMBA mean value: 0.007293169793169747 SD value: 0.005399484819993798
# sum_TMBC mean value: 0.011363636363636317 SD value: 0.007799719803778024
# sum_ELAVxSMBA mean value: 0.018030303030302983 SD value: 0.020944743429286518
# sum_TMBCxELAV mean value: 0.012085137085137043 SD value: 0.0135266473444621
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality unweighted=============================================
# sum_CsChBB mean value: 1.0 SD value: 0.0
# sum_w1118 mean value: 1.0 SD value: 0.0
# sum_ELAV mean value: 0.9986772486772486 SD value: 0.004605948504359878
# sum_SMBA mean value: 1.0 SD value: 0.0
# sum_TMBC mean value: 1.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.9916666666666666 SD value: 0.025000000000000078
# sum_TMBCxELAV mean value: 1.0 SD value: 0.0
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality weight=count=============================================
# sum_CsChBB mean value: 0.03351293673346667 SD value: 0.007274616655782796
# sum_w1118 mean value: 0.03434248367193863 SD value: 0.004023399832910595
# sum_ELAV mean value: 0.053612216648525314 SD value: 0.04346442086693765
# sum_SMBA mean value: 0.026292110852474744 SD value: 0.002766887189305711
# sum_TMBC mean value: 0.03689945423416419 SD value: 0.005231817695545026
# sum_ELAVxSMBA mean value: 0.03435520750930522 SD value: 0.021966981148511543
# sum_TMBCxELAV mean value: 0.0309386113847404 SD value: 0.0076148910464499215
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality weight=duration(seconds)=============================================
# sum_CsChBB mean value: 0.029847432104050463 SD value: 0.007385149400377803
# sum_w1118 mean value: 0.034090769631225905 SD value: 0.005419986771424101
# sum_ELAV mean value: 0.030291024993879583 SD value: 0.01794183815144474
# sum_SMBA mean value: 0.025296273868359205 SD value: 0.00296949309131702
# sum_TMBC mean value: 0.0355298316471055 SD value: 0.0052737215939171736
# sum_ELAVxSMBA mean value: 0.028096028444949323 SD value: 0.016043733466464594
# sum_TMBCxELAV mean value: 0.026420123945283074 SD value: 0.006984748205461137
# ==========================================================================================
# ==========================================================================================
# =============================================Newman modularity unweighted=============================================
# sum_CsChBB mean value: 0.0 SD value: 0.0
# sum_w1118 mean value: 0.0 SD value: 0.0
# sum_ELAV mean value: 0.0 SD value: 0.0
# sum_SMBA mean value: 0.0 SD value: 0.0
# sum_TMBC mean value: 0.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.0 SD value: 0.0
# sum_TMBCxELAV mean value: 0.0 SD value: 0.0
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# =============================================Newman_modularity weight=count=============================================
# sum_CsChBB mean value: 0.0 SD value: 0.0
# sum_w1118 mean value: 0.0 SD value: 0.0
# sum_ELAV mean value: 0.0 SD value: 0.0
# sum_SMBA mean value: 0.0 SD value: 0.0
# sum_TMBC mean value: 0.0 SD value: 0.0
# sum_ELAVxSMBA mean value: 0.0 SD value: 0.0
# sum_TMBCxELAV mean value: 0.0 SD value: 0.0
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# =============================================Newman_modularity weight=dration(seconds)=============================================
# sum_CsChBB mean value: 0.0 SD value: 3.510833468576701e-16
# sum_w1118 mean value: 3.700743415417188e-17 SD value: 2.842594954928449e-16
# sum_ELAV mean value: 1.586032892321652e-17 SD value: 3.880652265880496e-16
# sum_SMBA mean value: -5.2867763077388404e-17 SD value: 3.504458822430847e-16
# sum_TMBC mean value: -9.79608551139844e-17 SD value: 2.4348303611620013e-16
# sum_ELAVxSMBA mean value: 1.2212453270876723e-16 SD value: 3.383904413151877e-16
# sum_TMBCxELAV mean value: 6.872809200060493e-17 SD value: 2.8558380710135605e-16
# ==========================================================================================
# ==========================================================================================
