# %%
import os
import toml

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from src import settings
from src.utils import fileio

CONFIG_PATH = os.path.join(settings.CONFIG_DIR, "main.toml")
with open(CONFIG_PATH, "r") as file:
    config = toml.load(file)  

TREATMENTS = config['TREATMENTS']
INPUT_PATH = os.path.join(settings.RESULTS_DIR, "local_measures")

all_treatments = fileio.load_multiple_folders(INPUT_PATH)
all_treatments = {key: value for key, value in all_treatments.items() if key in config["TREATMENTS"]}

treatment_dataframes = pd.DataFrame()
for treatment_name, treatment_path in all_treatments.items():
    all_groups = fileio.load_files_from_folder(treatment_path)

    for group_name, group_path in all_groups.items():
        df = pd.read_csv(group_path, index_col=0)
        df.rename_axis("Fly")
        df['Treatment'] = treatment_name
        df['Group'] = group_name.replace(".csv", "")
        treatment_dataframes = pd.concat([treatment_dataframes, df])

treatment_dataframes = treatment_dataframes.set_index('Treatment', append=True)
treatment_dataframes = treatment_dataframes.set_index('Group', append=True)
combined_data_reset = treatment_dataframes.reset_index()

order = ["Cs_10D", "CsCh", "Cs_5DIZ", "LDA_5DIZ", "OCT_5DIZ", "LDA_OCT_5DIZ"] 
for measure_name in treatment_dataframes.columns:
    if measure_name == 'Treatment': continue
    
    treatment_sums = {}
    for treatment in TREATMENTS:
        treatment_sums[f'sum_{treatment}'] = combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]

    anova_result = scipy.stats.f_oneway(*treatment_sums.values())
    all_data = np.concatenate([*treatment_sums.values()])
    group_labels = []
    for treatment in TREATMENTS:
        group_labels.extend([treatment] * len(combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]))

    tukey_results = pairwise_tukeyhsd(all_data, group_labels)

    print('=' * 45 + measure_name + '=' * 45)
    for treatment in treatment_sums.keys():
        print(f"{treatment} mean value: {np.mean(treatment_sums[treatment])} SD value: {np.std(treatment_sums[treatment])}")

    print(tukey_results)

    plt.figure(figsize=(6, 4))
    sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', errorbar='sd', order=TREATMENTS)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
        
    sns.boxplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', order=TREATMENTS)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
    print('='*90)
# Out:
# =============================================Degree centrality=============================================
# sum_CS_10D mean value: 2.0 SD value: 0.0
# sum_CsCh mean value: 2.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 2.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 2.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 2.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 1.9738292011019285 SD value: 0.10409250484798392
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0082  0.0082  False
#       CS_10D      Cs_5DIZ      0.0   1.0 -0.0085  0.0085  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0081  0.0081  False
#       CS_10D LDA_OCT_5DIZ  -0.0262   0.0 -0.0362 -0.0161   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0086  0.0086  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0081  0.0081  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0077  0.0077  False
#         CsCh LDA_OCT_5DIZ  -0.0262   0.0 -0.0359 -0.0165   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0082  0.0082  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0  -0.008   0.008  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0262   0.0 -0.0361 -0.0162   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0085  0.0085  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0262   0.0 -0.0358 -0.0165   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0081  0.0081  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0262   0.0  0.0161  0.0362   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================In-degree centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9869146005509642 SD value: 0.037336463273911276
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0029  0.0029  False
#       CS_10D      Cs_5DIZ      0.0   1.0  -0.003   0.003  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0029  0.0029  False
#       CS_10D LDA_OCT_5DIZ  -0.0131   0.0 -0.0167 -0.0095   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0031  0.0031  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0029  0.0029  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0028  0.0028  False
#         CsCh LDA_OCT_5DIZ  -0.0131   0.0 -0.0166 -0.0096   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0029  0.0029  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0029  0.0029  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0131   0.0 -0.0166 -0.0095   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0  -0.003   0.003  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0131   0.0 -0.0165 -0.0096   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0029  0.0029  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0131   0.0  0.0095  0.0167   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================Out-degree centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9869146005509642 SD value: 0.09100035072131274
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0072  0.0072  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0074  0.0074  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0071  0.0071  False
#       CS_10D LDA_OCT_5DIZ  -0.0131 0.0003 -0.0219 -0.0043   True
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0075  0.0075  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0071  0.0071  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0068  0.0068  False
#         CsCh LDA_OCT_5DIZ  -0.0131 0.0002 -0.0216 -0.0046   True
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0072  0.0072  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0  -0.007   0.007  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0131 0.0003 -0.0218 -0.0044   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0074  0.0074  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0131 0.0001 -0.0215 -0.0047   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0071  0.0071  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0131 0.0003  0.0043  0.0219   True
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================Eigenvector centrality=============================================
# sum_CS_10D mean value: 0.28867513459481275 SD value: 5.551115123125783e-17
# sum_CsCh mean value: 0.28867513459481275 SD value: 5.551115123125783e-17
# sum_Cs_5DIZ mean value: 0.2886751345948128 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.2886751345948128 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.28867513459481275 SD value: 5.551115123125783e-17
# sum_LDA_OCT_5DIZ mean value: 0.2885849191225285 SD value: 0.007216494188801364
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh     -0.0    1.0 -0.0006 0.0006  False
#       CS_10D      Cs_5DIZ     -0.0    1.0 -0.0006 0.0006  False
#       CS_10D     LDA_5DIZ     -0.0    1.0 -0.0006 0.0006  False
#       CS_10D LDA_OCT_5DIZ  -0.0001 0.9991 -0.0008 0.0006  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0006 0.0006  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0006 0.0006  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0005 0.0005  False
#         CsCh LDA_OCT_5DIZ  -0.0001 0.9989 -0.0008 0.0006  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0006 0.0006  False
#      Cs_5DIZ     LDA_5DIZ     -0.0    1.0 -0.0006 0.0006  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0001 0.9991 -0.0008 0.0006  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0006 0.0006  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0001 0.9989 -0.0008 0.0006  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0006 0.0006  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0001 0.9991 -0.0006 0.0008  False
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================Closeness centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9876443001443002 SD value: 0.03386673105833756
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0027  0.0027  False
#       CS_10D      Cs_5DIZ      0.0   1.0 -0.0028  0.0028  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0026  0.0026  False
#       CS_10D LDA_OCT_5DIZ  -0.0124   0.0 -0.0156 -0.0091   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0028  0.0028  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0026  0.0026  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0025  0.0025  False
#         CsCh LDA_OCT_5DIZ  -0.0124   0.0 -0.0155 -0.0092   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0027  0.0027  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0026  0.0026  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0124   0.0 -0.0156 -0.0091   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0028  0.0028  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0124   0.0 -0.0155 -0.0092   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0026  0.0026  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0124   0.0  0.0091  0.0156   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================In-Strength distribution, w=count=============================================
# sum_CS_10D mean value: 193.6184210526316 SD value: 52.566073819576545
# sum_CsCh mean value: 240.84420289855072 SD value: 45.359286344672164
# sum_Cs_5DIZ mean value: 212.19166666666666 SD value: 35.91745068749854
# sum_LDA_5DIZ mean value: 230.06597222222223 SD value: 51.98042321553274
# sum_OCT_5DIZ mean value: 237.18859649122808 SD value: 46.13276466052241
# sum_LDA_OCT_5DIZ mean value: 240.37878787878788 SD value: 67.14790665558928
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#       CS_10D         CsCh  47.2258    0.0    34.64  59.8116   True
#       CS_10D      Cs_5DIZ  18.5732 0.0007   5.5674  31.5791   True
#       CS_10D     LDA_5DIZ  36.4476    0.0  23.9809  48.9142   True
#       CS_10D LDA_OCT_5DIZ  46.7604    0.0  31.3794  62.1414   True
#       CS_10D     OCT_5DIZ  43.5702    0.0  30.3987  56.7417   True
#         CsCh      Cs_5DIZ -28.6525    0.0 -41.0648 -16.2402   True
#         CsCh     LDA_5DIZ -10.7782 0.0987 -22.6244   1.0679  False
#         CsCh LDA_OCT_5DIZ  -0.4654    1.0 -15.3479  14.4171  False
#         CsCh     OCT_5DIZ  -3.6556 0.9622 -16.2414   8.9302  False
#      Cs_5DIZ     LDA_5DIZ  17.8743 0.0005   5.5829  30.1657   True
#      Cs_5DIZ LDA_OCT_5DIZ  28.1871    0.0  12.9478  43.4265   True
#      Cs_5DIZ     OCT_5DIZ  24.9969    0.0  11.9911  38.0027   True
#     LDA_5DIZ LDA_OCT_5DIZ  10.3128  0.348   -4.469  25.0947  False
#     LDA_5DIZ     OCT_5DIZ   7.1226 0.5784   -5.344  19.5893  False
# LDA_OCT_5DIZ     OCT_5DIZ  -3.1902 0.9916 -18.5712  12.1908  False
# ------------------------------------------------------------------
# ==========================================================================================
# =============================================Out-Strength distribution, w=count=============================================
# sum_CS_10D mean value: 193.6184210526316 SD value: 53.466164190975945
# sum_CsCh mean value: 240.84420289855072 SD value: 47.422029856059275
# sum_Cs_5DIZ mean value: 212.19166666666666 SD value: 38.13076094907569
# sum_LDA_5DIZ mean value: 230.06597222222223 SD value: 53.6570820416229
# sum_OCT_5DIZ mean value: 237.18859649122808 SD value: 47.53968288606221
# sum_LDA_OCT_5DIZ mean value: 240.37878787878788 SD value: 73.3333536814397
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#       CS_10D         CsCh  47.2258    0.0  34.0738  60.3778   True
#       CS_10D      Cs_5DIZ  18.5732 0.0014   4.9823  32.1642   True
#       CS_10D     LDA_5DIZ  36.4476    0.0  23.4201   49.475   True
#       CS_10D LDA_OCT_5DIZ  46.7604    0.0  30.6874  62.8333   True
#       CS_10D     OCT_5DIZ  43.5702    0.0  29.8061  57.3342   True
#         CsCh      Cs_5DIZ -28.6525    0.0 -41.6232 -15.6818   True
#         CsCh     LDA_5DIZ -10.7782 0.1293 -23.1573   1.6008  False
#         CsCh LDA_OCT_5DIZ  -0.4654    1.0 -16.0175  15.0866  False
#         CsCh     OCT_5DIZ  -3.6556 0.9687 -16.8076   9.4964  False
#      Cs_5DIZ     LDA_5DIZ  17.8743 0.0011   5.0299  30.7187   True
#      Cs_5DIZ LDA_OCT_5DIZ  28.1871    0.0  12.2622  44.1121   True
#      Cs_5DIZ     OCT_5DIZ  24.9969    0.0   11.406  38.5878   True
#     LDA_5DIZ LDA_OCT_5DIZ  10.3128 0.3993  -5.1341  25.7597  False
#     LDA_5DIZ     OCT_5DIZ   7.1226  0.625  -5.9048  20.1501  False
# LDA_OCT_5DIZ     OCT_5DIZ  -3.1902 0.9931 -19.2631  12.8828  False
# ------------------------------------------------------------------
# ==========================================================================================
# =============================================In-Strength distribution, w=duration=============================================
# sum_CS_10D mean value: 375.96984649122805 SD value: 140.43511084528333
# sum_CsCh mean value: 278.4381038647343 SD value: 67.12968573598839
# sum_Cs_5DIZ mean value: 284.6111111111111 SD value: 97.28406448310739
# sum_LDA_5DIZ mean value: 282.8454861111111 SD value: 84.730865106595
# sum_OCT_5DIZ mean value: 369.9740497076024 SD value: 204.99252737194277
# sum_LDA_OCT_5DIZ mean value: 388.96748737373736 SD value: 151.3656346512903
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#    group1       group2    meandiff p-adj    lower    upper   reject
# -------------------------------------------------------------------
#       CS_10D         CsCh -97.5317    0.0 -130.2046 -64.8588   True
#       CS_10D      Cs_5DIZ -91.3587    0.0  -125.122 -57.5955   True
#       CS_10D     LDA_5DIZ -93.1244    0.0 -125.4879 -60.7608   True
#       CS_10D LDA_OCT_5DIZ  12.9976 0.9391  -26.9316  52.9269  False
#       CS_10D     OCT_5DIZ  -5.9958 0.9962  -40.1892  28.1976  False
#         CsCh      Cs_5DIZ    6.173 0.9942  -26.0495  38.3955  False
#         CsCh     LDA_5DIZ   4.4074 0.9985  -26.3453  35.1601  False
#         CsCh LDA_OCT_5DIZ 110.5294    0.0   71.8942 149.1646   True
#         CsCh     OCT_5DIZ  91.5359    0.0    58.863 124.2089   True
#      Cs_5DIZ     LDA_5DIZ  -1.7656    1.0  -33.6744  30.1431  False
#      Cs_5DIZ LDA_OCT_5DIZ 104.3564    0.0   64.7948 143.9179   True
#      Cs_5DIZ     OCT_5DIZ  85.3629    0.0   51.5997 119.1262   True
#     LDA_5DIZ LDA_OCT_5DIZ  106.122    0.0   67.7481 144.4959   True
#     LDA_5DIZ     OCT_5DIZ  87.1286    0.0   54.7651 119.4921   True
# LDA_OCT_5DIZ     OCT_5DIZ -18.9934 0.7525  -58.9227  20.9358  False
# -------------------------------------------------------------------
# ==========================================================================================
# =============================================Out-Strength distribution, w=duration=============================================
# sum_CS_10D mean value: 375.96984649122805 SD value: 144.0936450339497
# sum_CsCh mean value: 278.43810386473433 SD value: 69.43507009230646
# sum_Cs_5DIZ mean value: 284.6111111111111 SD value: 97.93258186753928
# sum_LDA_5DIZ mean value: 282.8454861111111 SD value: 88.90590425183373
# sum_OCT_5DIZ mean value: 369.9740497076023 SD value: 205.52156841205772
# sum_LDA_OCT_5DIZ mean value: 388.96748737373736 SD value: 161.15435006634812
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#    group1       group2    meandiff p-adj    lower    upper   reject
# -------------------------------------------------------------------
#       CS_10D         CsCh -97.5317    0.0 -130.9288 -64.1347   True
#       CS_10D      Cs_5DIZ -91.3587    0.0 -125.8703 -56.8471   True
#       CS_10D     LDA_5DIZ -93.1244    0.0 -126.2052 -60.0435   True
#       CS_10D LDA_OCT_5DIZ  12.9976 0.9443  -27.8166  53.8119  False
#       CS_10D     OCT_5DIZ  -5.9958 0.9965   -40.947  28.9555  False
#         CsCh      Cs_5DIZ    6.173 0.9948  -26.7637  39.1097  False
#         CsCh     LDA_5DIZ   4.4074 0.9987  -27.0269  35.8417  False
#         CsCh LDA_OCT_5DIZ 110.5294    0.0   71.0379 150.0209   True
#         CsCh     OCT_5DIZ  91.5359    0.0   58.1389  124.933   True
#      Cs_5DIZ     LDA_5DIZ  -1.7656    1.0  -34.3816  30.8503  False
#      Cs_5DIZ LDA_OCT_5DIZ 104.3564    0.0    63.918 144.7948   True
#      Cs_5DIZ     OCT_5DIZ  85.3629    0.0   50.8513 119.8745   True
#     LDA_5DIZ LDA_OCT_5DIZ  106.122    0.0   66.8976 145.3464   True
#     LDA_5DIZ     OCT_5DIZ  87.1286    0.0   54.0477 120.2094   True
# LDA_OCT_5DIZ     OCT_5DIZ -18.9934 0.7695  -59.8077  21.8208  False
# -------------------------------------------------------------------
# ==========================================================================================
# =============================================Weighted Degree (count)=============================================
# sum_CS_10D mean value: 387.2368421052632 SD value: 104.14937843609145
# sum_CsCh mean value: 481.68840579710144 SD value: 90.23209210300182
# sum_Cs_5DIZ mean value: 424.3833333333333 SD value: 70.71458870385626
# sum_LDA_5DIZ mean value: 460.13194444444446 SD value: 103.16900552866976
# sum_OCT_5DIZ mean value: 474.37719298245617 SD value: 90.54211875869504
# sum_LDA_OCT_5DIZ mean value: 480.75757575757575 SD value: 137.556992112257
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#       CS_10D         CsCh  94.4516    0.0  69.3844 119.5187   True
#       CS_10D      Cs_5DIZ  37.1465 0.0006  11.2428  63.0501   True
#       CS_10D     LDA_5DIZ  72.8951    0.0  48.0654  97.7248   True
#       CS_10D LDA_OCT_5DIZ  93.5207    0.0  62.8864  124.155   True
#       CS_10D     OCT_5DIZ  87.1404    0.0  60.9067  113.374   True
#         CsCh      Cs_5DIZ -57.3051    0.0 -82.0266 -32.5835   True
#         CsCh     LDA_5DIZ -21.5565 0.0961 -45.1504   2.0374  False
#         CsCh LDA_OCT_5DIZ  -0.9308    1.0 -30.5723  28.7106  False
#         CsCh     OCT_5DIZ  -7.3112 0.9615 -32.3783  17.7559  False
#      Cs_5DIZ     LDA_5DIZ  35.7486 0.0005  11.2678  60.2294   True
#      Cs_5DIZ LDA_OCT_5DIZ  56.3742    0.0  26.0221  86.7264   True
#      Cs_5DIZ     OCT_5DIZ  49.9939    0.0  24.0902  75.8975   True
#     LDA_5DIZ LDA_OCT_5DIZ  20.6256 0.3432  -8.8154  50.0666  False
#     LDA_5DIZ     OCT_5DIZ  14.2452 0.5739 -10.5845   39.075  False
# LDA_OCT_5DIZ     OCT_5DIZ  -6.3804 0.9914 -37.0147  24.2539  False
# ------------------------------------------------------------------
# ==========================================================================================
# =============================================Weighted Degree (duration(seconds))=============================================
# sum_CS_10D mean value: 751.9396929824562 SD value: 277.5018065206082
# sum_CsCh mean value: 556.8762077294685 SD value: 133.13119617345896
# sum_Cs_5DIZ mean value: 569.2222222222222 SD value: 191.90514811960387
# sum_LDA_5DIZ mean value: 565.6909722222222 SD value: 170.46091184127826
# sum_OCT_5DIZ mean value: 739.9480994152048 SD value: 406.9785769057481
# sum_LDA_OCT_5DIZ mean value: 777.9349747474748 SD value: 305.03723089683075
#          Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================================
#    group1       group2     meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------------------
#       CS_10D         CsCh -195.0635    0.0 -260.0351 -130.0919   True
#       CS_10D      Cs_5DIZ -182.7175    0.0 -249.8573 -115.5777   True
#       CS_10D     LDA_5DIZ -186.2487    0.0 -250.6051 -121.8924   True
#       CS_10D LDA_OCT_5DIZ   25.9953 0.9376  -53.4059  105.3965  False
#       CS_10D     OCT_5DIZ  -11.9916 0.9961  -79.9867   56.0035  False
#         CsCh      Cs_5DIZ    12.346  0.994  -51.7299   76.4219  False
#         CsCh     LDA_5DIZ    8.8148 0.9985  -52.3384   69.9679  False
#         CsCh LDA_OCT_5DIZ  221.0588    0.0  144.2309  297.8866   True
#         CsCh     OCT_5DIZ  183.0719    0.0  118.1003  248.0435   True
#      Cs_5DIZ     LDA_5DIZ   -3.5313    1.0  -66.9833   59.9208  False
#      Cs_5DIZ LDA_OCT_5DIZ  208.7128    0.0  130.0428  287.3827   True
#      Cs_5DIZ     OCT_5DIZ  170.7259    0.0  103.5861  237.8657   True
#     LDA_5DIZ LDA_OCT_5DIZ   212.244    0.0  135.9357  288.5523   True
#     LDA_5DIZ     OCT_5DIZ  174.2571    0.0  109.9008  238.6135   True
# LDA_OCT_5DIZ     OCT_5DIZ  -37.9869 0.7479 -117.3881   41.4143  False
# ---------------------------------------------------------------------
# ==========================================================================================
# =============================================In-degree=============================================
# sum_CS_10D mean value: 11.0 SD value: 0.0
# sum_CsCh mean value: 11.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 11.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 11.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 11.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 10.856060606060606 SD value: 0.4107010960130242
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0324  0.0324  False
#       CS_10D      Cs_5DIZ      0.0   1.0 -0.0334  0.0334  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0321  0.0321  False
#       CS_10D LDA_OCT_5DIZ  -0.1439   0.0 -0.1835 -0.1044   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0339  0.0339  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0319  0.0319  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0305  0.0305  False
#         CsCh LDA_OCT_5DIZ  -0.1439   0.0 -0.1822 -0.1057   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0324  0.0324  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0316  0.0316  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.1439   0.0 -0.1831 -0.1047   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0334  0.0334  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.1439   0.0  -0.182 -0.1059   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0321  0.0321  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.1439   0.0  0.1044  0.1835   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================Out-degree=============================================
# sum_CS_10D mean value: 11.0 SD value: 0.0
# sum_CsCh mean value: 11.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 11.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 11.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 11.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 10.856060606060606 SD value: 1.0010038579344402
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0789  0.0789  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0815  0.0815  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0781  0.0781  False
#       CS_10D LDA_OCT_5DIZ  -0.1439 0.0003 -0.2404 -0.0475   True
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0826  0.0826  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0778  0.0778  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0743  0.0743  False
#         CsCh LDA_OCT_5DIZ  -0.1439 0.0002 -0.2372 -0.0506   True
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0789  0.0789  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0  -0.077   0.077  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.1439 0.0003 -0.2395 -0.0484   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0815  0.0815  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.1439 0.0001 -0.2366 -0.0513   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0781  0.0781  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.1439 0.0003  0.0475  0.2404   True
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================Selectivity=============================================
# sum_CS_10D mean value: nan SD value: nan
# sum_CsCh mean value: nan SD value: nan
# sum_Cs_5DIZ mean value: nan SD value: nan
# sum_LDA_5DIZ mean value: nan SD value: nan
# sum_OCT_5DIZ mean value: nan SD value: nan
# sum_LDA_OCT_5DIZ mean value: nan SD value: nan
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      nan   nan   nan   nan  False
#       CS_10D      Cs_5DIZ      nan   nan   nan   nan  False
#       CS_10D     LDA_5DIZ      nan   nan   nan   nan  False
#       CS_10D LDA_OCT_5DIZ      nan   nan   nan   nan  False
#       CS_10D     OCT_5DIZ      nan   nan   nan   nan  False
#         CsCh      Cs_5DIZ      nan   nan   nan   nan  False
#         CsCh     LDA_5DIZ      nan   nan   nan   nan  False
#         CsCh LDA_OCT_5DIZ      nan   nan   nan   nan  False
#         CsCh     OCT_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ     LDA_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ LDA_OCT_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
#     LDA_5DIZ LDA_OCT_5DIZ      nan   nan   nan   nan  False
#     LDA_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
# LDA_OCT_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
# -----------------------------------------------------------
# ==========================================================================================
# =============================================Betweenness centrality w=None=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.0005509641873278213 SD value: 0.001604897477978147
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0001  0.0001  False
#       CS_10D      Cs_5DIZ      0.0   1.0 -0.0001  0.0001  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0001  0.0001  False
#       CS_10D LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0001  0.0001  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0001  0.0001  False
#         CsCh LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0001  0.0001  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0006   0.0 -0.0007 -0.0004   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================Betweenness centrality w=count=============================================
# sum_CS_10D mean value: 0.0289772727272727 SD value: 0.07533388882776465
# sum_CsCh mean value: 0.009464207290294223 SD value: 0.019278959980765793
# sum_Cs_5DIZ mean value: 0.014119318181818158 SD value: 0.0426549873024915
# sum_LDA_5DIZ mean value: 0.01205281986531984 SD value: 0.035046057967260506
# sum_OCT_5DIZ mean value: 0.015782828282828256 SD value: 0.047198024273764634
# sum_LDA_OCT_5DIZ mean value: 0.03287419651056012 SD value: 0.10939878810740807
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh  -0.0195 0.0013 -0.0337 -0.0053   True
#       CS_10D      Cs_5DIZ  -0.0149 0.0447 -0.0295 -0.0002   True
#       CS_10D     LDA_5DIZ  -0.0169 0.0079  -0.031 -0.0029   True
#       CS_10D LDA_OCT_5DIZ   0.0039 0.9878 -0.0134  0.0212  False
#       CS_10D     OCT_5DIZ  -0.0132 0.1143  -0.028  0.0016  False
#         CsCh      Cs_5DIZ   0.0047 0.9333 -0.0093  0.0186  False
#         CsCh     LDA_5DIZ   0.0026 0.9938 -0.0108  0.0159  False
#         CsCh LDA_OCT_5DIZ   0.0234  0.001  0.0066  0.0402   True
#         CsCh     OCT_5DIZ   0.0063 0.8007 -0.0079  0.0205  False
#      Cs_5DIZ     LDA_5DIZ  -0.0021 0.9982 -0.0159  0.0118  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0188 0.0229  0.0016  0.0359   True
#      Cs_5DIZ     OCT_5DIZ   0.0017 0.9995  -0.013  0.0163  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0208  0.005  0.0042  0.0375   True
#     LDA_5DIZ     OCT_5DIZ   0.0037 0.9744 -0.0103  0.0178  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0171 0.0558 -0.0344  0.0002  False
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================Betweenness centrality w=duration(seconds)=============================================
# sum_CS_10D mean value: 0.0402113237639553 SD value: 0.08150837766357595
# sum_CsCh mean value: 0.016090250329380728 SD value: 0.02975697266208097
# sum_Cs_5DIZ mean value: 0.022253787878787845 SD value: 0.041886879336889046
# sum_LDA_5DIZ mean value: 0.019049873737373706 SD value: 0.04145131722802236
# sum_OCT_5DIZ mean value: 0.02416267942583729 SD value: 0.046685158840048674
# sum_LDA_OCT_5DIZ mean value: 0.04359504132231402 SD value: 0.10889409838745107
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh  -0.0241 0.0001 -0.0391 -0.0092   True
#       CS_10D      Cs_5DIZ   -0.018 0.0118 -0.0334 -0.0025   True
#       CS_10D     LDA_5DIZ  -0.0212 0.0007  -0.036 -0.0064   True
#       CS_10D LDA_OCT_5DIZ   0.0034  0.995 -0.0149  0.0216  False
#       CS_10D     OCT_5DIZ   -0.016 0.0401 -0.0317 -0.0004   True
#         CsCh      Cs_5DIZ   0.0062 0.8396 -0.0086  0.0209  False
#         CsCh     LDA_5DIZ    0.003  0.991 -0.0111   0.017  False
#         CsCh LDA_OCT_5DIZ   0.0275 0.0001  0.0098  0.0452   True
#         CsCh     OCT_5DIZ   0.0081 0.6364 -0.0069   0.023  False
#      Cs_5DIZ     LDA_5DIZ  -0.0032  0.989 -0.0178  0.0114  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0213 0.0101  0.0033  0.0394   True
#      Cs_5DIZ     OCT_5DIZ   0.0019 0.9993 -0.0135  0.0173  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0245  0.001   0.007  0.0421   True
#     LDA_5DIZ     OCT_5DIZ   0.0051 0.9223 -0.0097  0.0199  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0194 0.0291 -0.0377 -0.0012   True
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=None=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9912465564738292 SD value: 0.01794086388199676
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0   1.0 -0.0014  0.0014  False
#       CS_10D      Cs_5DIZ      0.0   1.0 -0.0015  0.0015  False
#       CS_10D     LDA_5DIZ      0.0   1.0 -0.0014  0.0014  False
#       CS_10D LDA_OCT_5DIZ  -0.0088   0.0 -0.0105  -0.007   True
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0015  0.0015  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0014  0.0014  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0013  0.0013  False
#         CsCh LDA_OCT_5DIZ  -0.0088   0.0 -0.0104 -0.0071   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0014  0.0014  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0014  0.0014  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0088   0.0 -0.0105  -0.007   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0015  0.0015  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0088   0.0 -0.0104 -0.0071   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0014  0.0014  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0088   0.0   0.007  0.0105   True
# ---------------------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=count=============================================
# sum_CS_10D mean value: 0.46905737708882617 SD value: 0.0950343288605182
# sum_CsCh mean value: 0.5557638704452255 SD value: 0.06387866417426746
# sum_Cs_5DIZ mean value: 0.5211000342187012 SD value: 0.06534846804453895
# sum_LDA_5DIZ mean value: 0.5162641030767694 SD value: 0.07538992461681467
# sum_OCT_5DIZ mean value: 0.511364251327807 SD value: 0.06461139476611341
# sum_LDA_OCT_5DIZ mean value: 0.46733272268119497 SD value: 0.09059773476968945
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh   0.0867    0.0  0.0674   0.106   True
#       CS_10D      Cs_5DIZ    0.052    0.0  0.0321  0.0719   True
#       CS_10D     LDA_5DIZ   0.0472    0.0  0.0281  0.0663   True
#       CS_10D LDA_OCT_5DIZ  -0.0017 0.9999 -0.0253  0.0218  False
#       CS_10D     OCT_5DIZ   0.0423    0.0  0.0222  0.0625   True
#         CsCh      Cs_5DIZ  -0.0347    0.0 -0.0537 -0.0157   True
#         CsCh     LDA_5DIZ  -0.0395    0.0 -0.0576 -0.0214   True
#         CsCh LDA_OCT_5DIZ  -0.0884    0.0 -0.1112 -0.0657   True
#         CsCh     OCT_5DIZ  -0.0444    0.0 -0.0637 -0.0251   True
#      Cs_5DIZ     LDA_5DIZ  -0.0048 0.9778 -0.0236   0.014  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0538    0.0 -0.0771 -0.0304   True
#      Cs_5DIZ     OCT_5DIZ  -0.0097 0.7296 -0.0296  0.0102  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0489    0.0 -0.0716 -0.0263   True
#     LDA_5DIZ     OCT_5DIZ  -0.0049 0.9779  -0.024  0.0142  False
# LDA_OCT_5DIZ     OCT_5DIZ    0.044    0.0  0.0205  0.0676   True
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=duration(seconds)=============================================
# sum_CS_10D mean value: 0.2977817350424966 SD value: 0.11964785676514718
# sum_CsCh mean value: 0.46348237937703646 SD value: 0.08737925268287766
# sum_Cs_5DIZ mean value: 0.43543937535388866 SD value: 0.08336429132443983
# sum_LDA_5DIZ mean value: 0.41675143645983925 SD value: 0.09339944069466327
# sum_OCT_5DIZ mean value: 0.37902360181940675 SD value: 0.09976473188905272
# sum_LDA_OCT_5DIZ mean value: 0.3408042900903299 SD value: 0.12012882524484994
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh   0.1657    0.0  0.1403  0.1911   True
#       CS_10D      Cs_5DIZ   0.1377    0.0  0.1114  0.1639   True
#       CS_10D     LDA_5DIZ    0.119    0.0  0.0938  0.1441   True
#       CS_10D LDA_OCT_5DIZ    0.043 0.0011   0.012  0.0741   True
#       CS_10D     OCT_5DIZ   0.0812    0.0  0.0546  0.1078   True
#         CsCh      Cs_5DIZ   -0.028  0.018 -0.0531  -0.003   True
#         CsCh     LDA_5DIZ  -0.0467    0.0 -0.0707 -0.0228   True
#         CsCh LDA_OCT_5DIZ  -0.1227    0.0 -0.1527 -0.0926   True
#         CsCh     OCT_5DIZ  -0.0845    0.0 -0.1099  -0.059   True
#      Cs_5DIZ     LDA_5DIZ  -0.0187  0.263 -0.0435  0.0061  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0946    0.0 -0.1254 -0.0639   True
#      Cs_5DIZ     OCT_5DIZ  -0.0564    0.0 -0.0827 -0.0302   True
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0759    0.0 -0.1058 -0.0461   True
#     LDA_5DIZ     OCT_5DIZ  -0.0377 0.0003 -0.0629 -0.0126   True
# LDA_OCT_5DIZ     OCT_5DIZ   0.0382 0.0061  0.0072  0.0693   True
# ----------------------------------------------------------------
# ==========================================================================================
# =============================================PageRank centrality=============================================
# sum_CS_10D mean value: 0.0833333333333333 SD value: 0.0
# sum_CsCh mean value: 0.0833333333333333 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.08333333333333329 SD value: 1.3877787807814457e-17
# sum_LDA_5DIZ mean value: 0.0833333333333333 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0833333333333333 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.08333333333333327 SD value: 0.0020426840330902817
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1       group2    meandiff p-adj  lower  upper  reject
# --------------------------------------------------------------
#       CS_10D         CsCh     -0.0   1.0 -0.0002 0.0002  False
#       CS_10D      Cs_5DIZ     -0.0   1.0 -0.0002 0.0002  False
#       CS_10D     LDA_5DIZ     -0.0   1.0 -0.0002 0.0002  False
#       CS_10D LDA_OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#       CS_10D     OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0002 0.0002  False
#         CsCh     LDA_5DIZ     -0.0   1.0 -0.0002 0.0002  False
#         CsCh LDA_OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#      Cs_5DIZ     LDA_5DIZ     -0.0   1.0 -0.0002 0.0002  False
#      Cs_5DIZ LDA_OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0002 0.0002  False
# LDA_OCT_5DIZ     OCT_5DIZ     -0.0   1.0 -0.0002 0.0002  False
# --------------------------------------------------------------
# ==========================================================================================
