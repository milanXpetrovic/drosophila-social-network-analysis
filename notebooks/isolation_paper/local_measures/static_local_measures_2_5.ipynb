# %%
import os
import toml
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np

from src import settings
from src.utils import fileio

CONFIG_PATH = os.path.join(settings.CONFIG_DIR, "main.toml")
with open(CONFIG_PATH, "r") as file:
    config = toml.load(file)  
INPUT_PATH = os.path.join(settings.RESULTS_DIR, "local_measures")
all_treatments = fileio.load_multiple_folders(INPUT_PATH)
all_treatments = {key: value for key, value in all_treatments.items() if key in config["TREATMENTS"]}

treatment_dataframes = pd.DataFrame()
for treatment_name, treatment_path in all_treatments.items():
    all_groups = fileio.load_files_from_folder(treatment_path)

    for group_name, group_path in all_groups.items():
        df = pd.read_csv(group_path, index_col=0)
        df.rename_axis("Fly")
        df['Treatment'] = treatment_name
        df['Group'] = group_name.replace(".csv", "")
        treatment_dataframes = pd.concat([treatment_dataframes, df])

treatment_dataframes = treatment_dataframes.set_index('Treatment', append=True)
treatment_dataframes = treatment_dataframes.set_index('Group',append=True)

combined_data_reset = treatment_dataframes.reset_index()

order = ["CsCh", "Cs_5DIZ", "LDA_5DIZ", "OCT_5DIZ", "LDA_OCT_5DIZ"] 
for measure_name in treatment_dataframes.columns:
    sum_CsCh = combined_data_reset[combined_data_reset['Treatment']=='CsCh'][measure_name]
    sum_Cs_5DIZ = combined_data_reset[combined_data_reset['Treatment']=='Cs_5DIZ'][measure_name]
    sum_LDA_5DIZ = combined_data_reset[combined_data_reset['Treatment']=='LDA_5DIZ'][measure_name]
    sum_OCT_5DIZ = combined_data_reset[combined_data_reset['Treatment']=='OCT_5DIZ'][measure_name]
    sum_LDA_OCT_5DIZ = combined_data_reset[combined_data_reset['Treatment']=='LDA_OCT_5DIZ'][measure_name]

    anova_result = scipy.stats.f_oneway(sum_CsCh, sum_Cs_5DIZ, sum_LDA_5DIZ, sum_OCT_5DIZ, sum_LDA_OCT_5DIZ)

    all_data = np.concatenate([sum_CsCh, sum_Cs_5DIZ, sum_LDA_5DIZ, sum_OCT_5DIZ, sum_LDA_OCT_5DIZ])
    group_labels = ['CsCh'] * len(sum_CsCh) + ['Cs_5DIZ'] * len(sum_Cs_5DIZ) + ['LDA_5DIZ'] * len(sum_LDA_5DIZ) + ['OCT_5DIZ'] * len(sum_OCT_5DIZ) + ['LDA_OCT_5DIZ'] * len(sum_LDA_OCT_5DIZ)
    tukey_results = pairwise_tukeyhsd(all_data, group_labels)


    if any(tukey_results.reject):
        print(tukey_results)
        # print('Number of groups')
        # print(f'cScH: {int(len(sum_CsCh)/12)}  Cs5DIZ: {int(len(sum_Cs_5DIZ)/12)}  LDA: {int(len(sum_LDA_5DIZ)/12)}  OCT: {int(len(sum_OCT_5DIZ)/12)}')
        # print('Number of samples')
        # print(f'cScH: {len(sum_CsCh)}  Cs5DIZ: {len(sum_Cs_5DIZ)}  LDA: {len(sum_LDA_5DIZ)}  OCT: {len(sum_OCT_5DIZ)} \n')

        plt.figure(figsize=(6, 4))
        order = ['CsCh', 'Cs_5DIZ', 'LDA_5DIZ', 'OCT_5DIZ', 'LDA_OCT_5DIZ'] 
        # sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, hue='Treatment', errorbar='sd', order=order)
        sns.boxplot(data=combined_data_reset, x='Treatment', y=measure_name, hue='Treatment', order=order)
        
        plt.xlabel('Treatment')
        plt.ylabel(measure_name)
        plt.title(f'Distribution of {measure_name}', fontsize=18)
        plt.legend('')
        plt.show()
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0085  0.0085  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0081  0.0081  False
#         CsCh LDA_OCT_5DIZ  -0.0262   0.0 -0.0363  -0.016   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0086  0.0086  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0084  0.0084  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0262   0.0 -0.0366 -0.0158   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0089  0.0089  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0262   0.0 -0.0363 -0.0161   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0085  0.0085  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0262   0.0  0.0157  0.0367   True
# ---------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0  -0.003   0.003  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0029  0.0029  False
#         CsCh LDA_OCT_5DIZ  -0.0131   0.0 -0.0167 -0.0094   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0031  0.0031  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0  -0.003   0.003  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0131   0.0 -0.0168 -0.0094   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0032  0.0032  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0131   0.0 -0.0167 -0.0095   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0031  0.0031  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0131   0.0  0.0093  0.0169   True
# ---------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0074  0.0074  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0071  0.0071  False
#         CsCh LDA_OCT_5DIZ  -0.0131 0.0006  -0.022 -0.0042   True
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0075  0.0075  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0073  0.0073  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0131 0.0008 -0.0222  -0.004   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0078  0.0078  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0131 0.0005 -0.0219 -0.0043   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0074  0.0074  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0131  0.001  0.0039  0.0223   True
# ----------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0028  0.0028  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0026  0.0026  False
#         CsCh LDA_OCT_5DIZ  -0.0124   0.0 -0.0157 -0.0091   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0028  0.0028  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0027  0.0027  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0124   0.0 -0.0157  -0.009   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0029  0.0029  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0124   0.0 -0.0156 -0.0091   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0028  0.0028  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0124   0.0  0.0089  0.0158   True
# ---------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#         CsCh      Cs_5DIZ -28.6525    0.0 -40.3685 -16.9366   True
#         CsCh     LDA_5DIZ -10.7782 0.0651 -21.9598   0.4033  False
#         CsCh LDA_OCT_5DIZ  -0.4654    1.0  -14.513  13.5822  False
#         CsCh     OCT_5DIZ  -3.6556 0.9179 -15.5353   8.2241  False
#      Cs_5DIZ     LDA_5DIZ  17.8743 0.0003   6.2724  29.4762   True
#      Cs_5DIZ LDA_OCT_5DIZ  28.1871    0.0  13.8027  42.5715   True
#      Cs_5DIZ     OCT_5DIZ  24.9969    0.0  12.7208  37.2731   True
#     LDA_5DIZ LDA_OCT_5DIZ  10.3128 0.2572  -3.6398  24.2654  False
#     LDA_5DIZ     OCT_5DIZ   7.1226 0.4633  -4.6446  18.8898  False
# LDA_OCT_5DIZ     OCT_5DIZ  -3.1902  0.975 -17.7083  11.3279  False
# ------------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#         CsCh      Cs_5DIZ -28.6525    0.0 -40.9695 -16.3356   True
#         CsCh     LDA_5DIZ -10.7782 0.0902 -22.5334   0.9769  False
#         CsCh LDA_OCT_5DIZ  -0.4654    1.0 -15.2336  14.3028  False
#         CsCh     OCT_5DIZ  -3.6556 0.9307 -16.1447   8.8335  False
#      Cs_5DIZ     LDA_5DIZ  17.8743 0.0006   5.6773  30.0713   True
#      Cs_5DIZ LDA_OCT_5DIZ  28.1871    0.0  13.0648  43.3094   True
#      Cs_5DIZ     OCT_5DIZ  24.9969    0.0   12.091  37.9028   True
#     LDA_5DIZ LDA_OCT_5DIZ  10.3128 0.3067  -4.3555  24.9811  False
#     LDA_5DIZ     OCT_5DIZ   7.1226 0.5151  -5.2482  19.4935  False
# LDA_OCT_5DIZ     OCT_5DIZ  -3.1902 0.9792  -18.453  12.0727  False
# ------------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#         CsCh      Cs_5DIZ    6.173 0.9809 -24.0342  36.3802  False
#         CsCh     LDA_5DIZ   4.4074 0.9936 -24.4219  33.2367  False
#         CsCh LDA_OCT_5DIZ 110.5294    0.0  74.3106 146.7482   True
#         CsCh     OCT_5DIZ  91.5359    0.0  60.9065 122.1653   True
#      Cs_5DIZ     LDA_5DIZ  -1.7656 0.9998 -31.6786  28.1474  False
#      Cs_5DIZ LDA_OCT_5DIZ 104.3564    0.0  67.2692 141.4436   True
#      Cs_5DIZ     OCT_5DIZ  85.3629    0.0  53.7114 117.0145   True
#     LDA_5DIZ LDA_OCT_5DIZ  106.122    0.0  70.1482 142.0958   True
#     LDA_5DIZ     OCT_5DIZ  87.1286    0.0  56.7892 117.4679   True
# LDA_OCT_5DIZ     OCT_5DIZ -18.9934 0.6366 -56.4254  18.4385  False
# ------------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#         CsCh      Cs_5DIZ    6.173 0.9823 -24.6746  37.0206  False
#         CsCh     LDA_5DIZ   4.4074 0.9941 -25.0331  33.8479  False
#         CsCh LDA_OCT_5DIZ 110.5294    0.0  73.5427  147.516   True
#         CsCh     OCT_5DIZ  91.5359    0.0  60.2572 122.8147   True
#      Cs_5DIZ     LDA_5DIZ  -1.7656 0.9999 -32.3128  28.7816  False
#      Cs_5DIZ LDA_OCT_5DIZ 104.3564    0.0  66.4829 142.2299   True
#      Cs_5DIZ     OCT_5DIZ  85.3629    0.0  53.0403 117.6855   True
#     LDA_5DIZ LDA_OCT_5DIZ  106.122    0.0  69.3855 142.8585   True
#     LDA_5DIZ     OCT_5DIZ  87.1286    0.0   56.146 118.1111   True
# LDA_OCT_5DIZ     OCT_5DIZ -18.9934 0.6551 -57.2189  19.2321  False
# ------------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#         CsCh      Cs_5DIZ -57.3051    0.0 -80.6676 -33.9425   True
#         CsCh     LDA_5DIZ -21.5565 0.0638 -43.8534   0.7404  False
#         CsCh LDA_OCT_5DIZ  -0.9308    1.0 -28.9428  27.0812  False
#         CsCh     OCT_5DIZ  -7.3112  0.917 -31.0003  16.3779  False
#      Cs_5DIZ     LDA_5DIZ  35.7486 0.0003  12.6135  58.8837   True
#      Cs_5DIZ LDA_OCT_5DIZ  56.3742    0.0  27.6906  85.0579   True
#      Cs_5DIZ     OCT_5DIZ  49.9939    0.0  25.5142  74.4735   True
#     LDA_5DIZ LDA_OCT_5DIZ  20.6256 0.2544  -7.1969  48.4482  False
#     LDA_5DIZ     OCT_5DIZ  14.2452 0.4602  -9.2196  37.7101  False
# LDA_OCT_5DIZ     OCT_5DIZ  -6.3804 0.9748 -35.3307  22.5699  False
# ------------------------------------------------------------------
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#    group1       group2    meandiff p-adj    lower    upper   reject
# -------------------------------------------------------------------
#         CsCh      Cs_5DIZ   12.346 0.9806  -47.8156  72.5076  False
#         CsCh     LDA_5DIZ   8.8148 0.9935  -48.6026  66.2321  False
#         CsCh LDA_OCT_5DIZ 221.0588    0.0  148.9243 293.1933   True
#         CsCh     OCT_5DIZ 183.0719    0.0  122.0694 244.0744   True
#      Cs_5DIZ     LDA_5DIZ  -3.5313 0.9998   -63.107  56.0445  False
#      Cs_5DIZ LDA_OCT_5DIZ 208.7128    0.0  134.8487 282.5768   True
#      Cs_5DIZ     OCT_5DIZ 170.7259    0.0  107.6876 233.7642   True
#     LDA_5DIZ LDA_OCT_5DIZ  212.244    0.0  140.5974 283.8907   True
#     LDA_5DIZ     OCT_5DIZ 174.2571    0.0  113.8323  234.682   True
# LDA_OCT_5DIZ     OCT_5DIZ -37.9869 0.6329 -112.5375  36.5638  False
# -------------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0334  0.0334  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0319  0.0319  False
#         CsCh LDA_OCT_5DIZ  -0.1439   0.0  -0.184 -0.1039   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0339  0.0339  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0331  0.0331  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.1439   0.0  -0.185 -0.1029   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0  -0.035   0.035  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.1439   0.0 -0.1837 -0.1041   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0336  0.0336  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.1439   0.0  0.1025  0.1854   True
# ---------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0815  0.0815  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0777  0.0777  False
#         CsCh LDA_OCT_5DIZ  -0.1439 0.0006 -0.2416 -0.0463   True
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0826  0.0826  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0807  0.0807  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.1439 0.0008  -0.244 -0.0439   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0854  0.0854  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.1439 0.0005 -0.2409 -0.0469   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0818  0.0818  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.1439  0.001   0.043  0.2449   True
# ----------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0001  0.0001  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0001  0.0001  False
#         CsCh LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0001  0.0001  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0006   0.0  0.0004  0.0007   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0001  0.0001  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0006   0.0 -0.0007 -0.0004   True
# ---------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ   0.0047 0.8367 -0.0076  0.0169  False
#         CsCh     LDA_5DIZ   0.0026 0.9742 -0.0091  0.0143  False
#         CsCh LDA_OCT_5DIZ   0.0234 0.0001  0.0087  0.0381   True
#         CsCh     OCT_5DIZ   0.0063 0.6328 -0.0061  0.0187  False
#      Cs_5DIZ     LDA_5DIZ  -0.0021 0.9903 -0.0142    0.01  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0188  0.006  0.0037  0.0338   True
#      Cs_5DIZ     OCT_5DIZ   0.0017 0.9966 -0.0111  0.0145  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0208 0.0009  0.0063  0.0354   True
#     LDA_5DIZ     OCT_5DIZ   0.0037 0.9214 -0.0086   0.016  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0171 0.0179 -0.0322 -0.0019   True
# ----------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ   0.0062  0.676 -0.0066  0.0189  False
#         CsCh     LDA_5DIZ    0.003 0.9635 -0.0092  0.0151  False
#         CsCh LDA_OCT_5DIZ   0.0275    0.0  0.0123  0.0428   True
#         CsCh     OCT_5DIZ   0.0081 0.4277 -0.0048   0.021  False
#      Cs_5DIZ     LDA_5DIZ  -0.0032 0.9576 -0.0158  0.0094  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0213 0.0018  0.0057   0.037   True
#      Cs_5DIZ     OCT_5DIZ   0.0019  0.995 -0.0114  0.0152  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0245 0.0001  0.0094  0.0397   True
#     LDA_5DIZ     OCT_5DIZ   0.0051 0.8098 -0.0077  0.0179  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0194  0.007 -0.0352 -0.0037   True
# ----------------------------------------------------------------
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1       group2    meandiff p-adj  lower  upper  reject
# --------------------------------------------------------------
#         CsCh      Cs_5DIZ      0.0   1.0 -0.0015 0.0015  False
#         CsCh     LDA_5DIZ      0.0   1.0 -0.0014 0.0014  False
#         CsCh LDA_OCT_5DIZ  -0.0088   0.0 -0.0105 -0.007   True
#         CsCh     OCT_5DIZ      0.0   1.0 -0.0015 0.0015  False
#      Cs_5DIZ     LDA_5DIZ      0.0   1.0 -0.0014 0.0014  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0088   0.0 -0.0105 -0.007   True
#      Cs_5DIZ     OCT_5DIZ      0.0   1.0 -0.0015 0.0015  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0088   0.0 -0.0105 -0.007   True
#     LDA_5DIZ     OCT_5DIZ      0.0   1.0 -0.0015 0.0015  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0088   0.0  0.0069 0.0106   True
# --------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ  -0.0347    0.0 -0.0518 -0.0176   True
#         CsCh     LDA_5DIZ  -0.0395    0.0 -0.0558 -0.0232   True
#         CsCh LDA_OCT_5DIZ  -0.0884    0.0 -0.1089 -0.0679   True
#         CsCh     OCT_5DIZ  -0.0444    0.0 -0.0617 -0.0271   True
#      Cs_5DIZ     LDA_5DIZ  -0.0048 0.9362 -0.0218  0.0121  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0538    0.0 -0.0748 -0.0328   True
#      Cs_5DIZ     OCT_5DIZ  -0.0097 0.5724 -0.0276  0.0082  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0489    0.0 -0.0693 -0.0286   True
#     LDA_5DIZ     OCT_5DIZ  -0.0049 0.9365 -0.0221  0.0123  False
# LDA_OCT_5DIZ     OCT_5DIZ    0.044    0.0  0.0229  0.0652   True
# ----------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#         CsCh      Cs_5DIZ   -0.028 0.0076  -0.051 -0.0051   True
#         CsCh     LDA_5DIZ  -0.0467    0.0 -0.0686 -0.0249   True
#         CsCh LDA_OCT_5DIZ  -0.1227    0.0 -0.1501 -0.0952   True
#         CsCh     OCT_5DIZ  -0.0845    0.0 -0.1077 -0.0612   True
#      Cs_5DIZ     LDA_5DIZ  -0.0187 0.1621 -0.0414   0.004  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0946    0.0 -0.1228 -0.0665   True
#      Cs_5DIZ     OCT_5DIZ  -0.0564    0.0 -0.0804 -0.0324   True
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0759    0.0 -0.1032 -0.0487   True
#     LDA_5DIZ     OCT_5DIZ  -0.0377 0.0001 -0.0607 -0.0147   True
# LDA_OCT_5DIZ     OCT_5DIZ   0.0382 0.0023  0.0098  0.0666   True
# ----------------------------------------------------------------
