# %%
import os
import toml

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from src import settings
from src.utils import fileio

CONFIG_PATH = os.path.join(settings.CONFIG_DIR, "main.toml")
with open(CONFIG_PATH, "r") as file:
    config = toml.load(file)  

TREATMENTS = config['TREATMENTS']
INPUT_PATH = os.path.join(settings.RESULTS_DIR, "local_measures")

all_treatments = fileio.load_multiple_folders(INPUT_PATH)
all_treatments = {key: value for key, value in all_treatments.items() if key in config["TREATMENTS"]}

treatment_dataframes = pd.DataFrame()
for treatment_name, treatment_path in all_treatments.items():
    all_groups = fileio.load_files_from_folder(treatment_path)

    for group_name, group_path in all_groups.items():
        df = pd.read_csv(group_path, index_col=0)
        df.rename_axis("Fly")
        df['Treatment'] = treatment_name
        df['Group'] = group_name.replace(".csv", "")
        treatment_dataframes = pd.concat([treatment_dataframes, df])

treatment_dataframes = treatment_dataframes.set_index('Treatment', append=True)
treatment_dataframes = treatment_dataframes.set_index('Group', append=True)
combined_data_reset = treatment_dataframes.reset_index()

order = ["Cs_10D", "CsCh", "Cs_5DIZ", "LDA_5DIZ", "OCT_5DIZ", "LDA_OCT_5DIZ"] 
for measure_name in treatment_dataframes.columns:
    if measure_name == 'Treatment': continue
    
    treatment_sums = {}
    for treatment in TREATMENTS:
        treatment_sums[f'sum_{treatment}'] = combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]

    anova_result = scipy.stats.f_oneway(*treatment_sums.values())
    all_data = np.concatenate([*treatment_sums.values()])
    group_labels = []
    for treatment in TREATMENTS:
        group_labels.extend([treatment] * len(combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]))

    tukey_results = pairwise_tukeyhsd(all_data, group_labels)

    print('=' * 45 + measure_name + '=' * 45)
    for treatment in treatment_sums.keys():
        print(f"{treatment} mean value: {np.mean(treatment_sums[treatment])} SD value: {np.std(treatment_sums[treatment])}")

    print(tukey_results)

    # plt.figure(figsize=(6, 4))
    # sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, hue='Treatment', errorbar='sd', order=config['TREATMENTS'])
    # plt.xlabel('Treatment')
    # plt.xticks(rotation=45)
    # plt.ylabel(measure_name)
    # plt.title(f'Distribution of {measure_name}', fontsize=18)
    # plt.legend().remove()
    # plt.show()

    plt.figure(figsize=(6, 4))
    sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, hue='Treatment', errorbar='se', order=config['TREATMENTS'])
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend().remove()
    plt.show()
        
    # sns.boxplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', order=TREATMENTS)
    # plt.xlabel('Treatment')
    # plt.xticks(rotation=45)
    # plt.ylabel(measure_name)
    # plt.title(f'Distribution of {measure_name}', fontsize=18)
    # plt.legend('')
    # plt.show() 
    # print('='*90)
# Out:
# =============================================Degree centrality=============================================
# sum_CS_10D mean value: 2.0 SD value: 0.0
# sum_CsCh mean value: 2.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 2.0 SD value: 0.0
# sum_ISOISO mean value: 1.9444444444444444 SD value: 0.16497457546526342
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0085  0.0085  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0085  0.0085  False
#  CS_10D  ISOISO  -0.0556   0.0 -0.0722 -0.0389   True
#    CsCh Cs_5DIZ      0.0   1.0 -0.0085  0.0085  False
#    CsCh  ISOISO  -0.0556   0.0 -0.0722 -0.0389   True
# Cs_5DIZ  ISOISO  -0.0556   0.0 -0.0722 -0.0389   True
# -----------------------------------------------------
# ==========================================================================================
# =============================================In-degree centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_ISOISO mean value: 0.9722222222222222 SD value: 0.041876575635800474
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0022  0.0022  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0022  0.0022  False
#  CS_10D  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
#    CsCh Cs_5DIZ      0.0   1.0 -0.0022  0.0022  False
#    CsCh  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
# Cs_5DIZ  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
# -----------------------------------------------------
# ==========================================================================================
# =============================================Out-degree centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_ISOISO mean value: 0.9722222222222222 SD value: 0.16433554953054488
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh      0.0    1.0 -0.0085  0.0085  False
#  CS_10D Cs_5DIZ      0.0    1.0 -0.0085  0.0085  False
#  CS_10D  ISOISO  -0.0278 0.0001 -0.0443 -0.0112   True
#    CsCh Cs_5DIZ      0.0    1.0 -0.0085  0.0085  False
#    CsCh  ISOISO  -0.0278 0.0001 -0.0443 -0.0112   True
# Cs_5DIZ  ISOISO  -0.0278 0.0001 -0.0443 -0.0112   True
# ------------------------------------------------------
# ==========================================================================================
# =============================================Eigenvector centrality=============================================
# sum_CS_10D mean value: 0.2886751345948128 SD value: 0.0
# sum_CsCh mean value: 0.2886751345948128 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.2886751345948128 SD value: 0.0
# sum_ISOISO mean value: 0.2886390077452392 SD value: 0.004566896230162645
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj   lower  upper  reject
# -----------------------------------------------------
#  CS_10D    CsCh      0.0    1.0 -0.0002 0.0002  False
#  CS_10D Cs_5DIZ      0.0    1.0 -0.0002 0.0002  False
#  CS_10D  ISOISO     -0.0 0.9971 -0.0005 0.0004  False
#    CsCh Cs_5DIZ      0.0    1.0 -0.0002 0.0002  False
#    CsCh  ISOISO     -0.0 0.9971 -0.0005 0.0004  False
# Cs_5DIZ  ISOISO     -0.0 0.9971 -0.0005 0.0004  False
# -----------------------------------------------------
# ==========================================================================================
# =============================================Closeness centrality=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_ISOISO mean value: 0.9722222222222222 SD value: 0.041876575635800474
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0022  0.0022  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0022  0.0022  False
#  CS_10D  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
#    CsCh Cs_5DIZ      0.0   1.0 -0.0022  0.0022  False
#    CsCh  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
# Cs_5DIZ  ISOISO  -0.0278   0.0  -0.032 -0.0236   True
# -----------------------------------------------------
# ==========================================================================================
# =============================================In-Strength distribution, w=count=============================================
# sum_CS_10D mean value: 192.84583333333333 SD value: 51.38349669532903
# sum_CsCh mean value: 239.175 SD value: 46.91404595996101
# sum_Cs_5DIZ mean value: 212.19166666666666 SD value: 35.91745068749854
# sum_ISOISO mean value: 402.25 SD value: 230.4944413646455
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1  group2 meandiff p-adj   lower    upper   reject
# --------------------------------------------------------
#  CS_10D    CsCh  46.3292    0.0  30.5617  62.0967   True
#  CS_10D Cs_5DIZ  19.3458 0.0089   3.5783  35.1133   True
#  CS_10D  ISOISO 209.4042    0.0 178.5331 240.2752   True
#    CsCh Cs_5DIZ -26.9833 0.0001 -42.7508 -11.2158   True
#    CsCh  ISOISO  163.075    0.0  132.204  193.946   True
# Cs_5DIZ  ISOISO 190.0583    0.0 159.1873 220.9294   True
# --------------------------------------------------------
# ==========================================================================================
# =============================================Out-Strength distribution, w=count=============================================
# sum_CS_10D mean value: 192.84583333333333 SD value: 52.03537642129204
# sum_CsCh mean value: 239.175 SD value: 48.78458815719025
# sum_Cs_5DIZ mean value: 212.19166666666666 SD value: 38.13076094907569
# sum_ISOISO mean value: 402.25 SD value: 263.09486829321133
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1  group2 meandiff p-adj   lower    upper   reject
# --------------------------------------------------------
#  CS_10D    CsCh  46.3292    0.0  29.0547  63.6036   True
#  CS_10D Cs_5DIZ  19.3458  0.021   2.0714  36.6203   True
#  CS_10D  ISOISO 209.4042    0.0 175.5827 243.2256   True
#    CsCh Cs_5DIZ -26.9833 0.0004 -44.2578  -9.7089   True
#    CsCh  ISOISO  163.075    0.0 129.2536 196.8964   True
# Cs_5DIZ  ISOISO 190.0583    0.0 156.2369 223.8798   True
# --------------------------------------------------------
# ==========================================================================================
# =============================================In-Strength distribution, w=duration=============================================
# sum_CS_10D mean value: 384.4836805555556 SD value: 149.2341620454486
# sum_CsCh mean value: 276.56336805555554 SD value: 69.69873704742245
# sum_Cs_5DIZ mean value: 284.6111111111111 SD value: 97.28406448310739
# sum_ISOISO mean value: 566.6006944444445 SD value: 231.02171067654203
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#  group1  group2  meandiff p-adj    lower    upper   reject
# ----------------------------------------------------------
#  CS_10D    CsCh -107.9203    0.0 -135.9622 -79.8784   True
#  CS_10D Cs_5DIZ  -99.8726    0.0 -127.9145 -71.8307   True
#  CS_10D  ISOISO   182.117    0.0   127.214   237.02   True
#    CsCh Cs_5DIZ    8.0477 0.8813  -19.9942  36.0897  False
#    CsCh  ISOISO  290.0373    0.0  235.1344 344.9403   True
# Cs_5DIZ  ISOISO  281.9896    0.0  227.0866 336.8926   True
# ----------------------------------------------------------
# ==========================================================================================
# =============================================Out-Strength distribution, w=duration=============================================
# sum_CS_10D mean value: 384.4836805555556 SD value: 152.6293643679233
# sum_CsCh mean value: 276.5633680555556 SD value: 72.10885215320629
# sum_Cs_5DIZ mean value: 284.6111111111111 SD value: 97.93258186753928
# sum_ISOISO mean value: 566.6006944444446 SD value: 274.07107495260266
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#  group1  group2  meandiff p-adj    lower    upper   reject
# ----------------------------------------------------------
#  CS_10D    CsCh -107.9203    0.0 -137.4192 -78.4214   True
#  CS_10D Cs_5DIZ  -99.8726    0.0 -129.3715 -70.3737   True
#  CS_10D  ISOISO   182.117    0.0  124.3614 239.8726   True
#    CsCh Cs_5DIZ    8.0477 0.8961  -21.4512  37.5466  False
#    CsCh  ISOISO  290.0373    0.0  232.2817 347.7929   True
# Cs_5DIZ  ISOISO  281.9896    0.0   224.234 339.7452   True
# ----------------------------------------------------------
# ==========================================================================================
# =============================================Weighted Degree (count)=============================================
# sum_CS_10D mean value: 385.69166666666666 SD value: 101.39894771259819
# sum_CsCh mean value: 478.35 SD value: 93.0738192690798
# sum_Cs_5DIZ mean value: 424.3833333333333 SD value: 70.71458870385626
# sum_ISOISO mean value: 804.5 SD value: 472.64201275618973
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1  group2 meandiff p-adj   lower    upper   reject
# --------------------------------------------------------
#  CS_10D    CsCh  92.6583    0.0  60.8306 124.4861   True
#  CS_10D Cs_5DIZ  38.6917 0.0098   6.8639  70.5194   True
#  CS_10D  ISOISO 418.8083    0.0 356.4931 481.1235   True
#    CsCh Cs_5DIZ -53.9667 0.0001 -85.7944 -22.1389   True
#    CsCh  ISOISO   326.15    0.0 263.8348 388.4652   True
# Cs_5DIZ  ISOISO 380.1167    0.0 317.8015 442.4319   True
# --------------------------------------------------------
# ==========================================================================================
# =============================================Weighted Degree (duration(seconds))=============================================
# sum_CS_10D mean value: 768.9673611111112 SD value: 292.9704287079477
# sum_CsCh mean value: 553.1267361111112 SD value: 138.52492431165857
# sum_Cs_5DIZ mean value: 569.2222222222222 SD value: 191.90514811960387
# sum_ISOISO mean value: 1133.2013888888891 SD value: 477.92454691144417
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#  group1  group2  meandiff p-adj    lower     upper   reject
# -----------------------------------------------------------
#  CS_10D    CsCh -215.8406    0.0 -271.5642  -160.117   True
#  CS_10D Cs_5DIZ -199.7451    0.0 -255.4687 -144.0215   True
#  CS_10D  ISOISO   364.234    0.0  255.1333  473.3347   True
#    CsCh Cs_5DIZ   16.0955 0.8793  -39.6281   71.8191  False
#    CsCh  ISOISO  580.0747    0.0   470.974  689.1754   True
# Cs_5DIZ  ISOISO  563.9792    0.0  454.8785  673.0799   True
# -----------------------------------------------------------
# ==========================================================================================
# =============================================In-degree=============================================
# sum_CS_10D mean value: 11.0 SD value: 0.0
# sum_CsCh mean value: 11.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 11.0 SD value: 0.0
# sum_ISOISO mean value: 10.694444444444445 SD value: 0.4606423319938055
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0237  0.0237  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0237  0.0237  False
#  CS_10D  ISOISO  -0.3056   0.0 -0.3519 -0.2592   True
#    CsCh Cs_5DIZ      0.0   1.0 -0.0237  0.0237  False
#    CsCh  ISOISO  -0.3056   0.0 -0.3519 -0.2592   True
# Cs_5DIZ  ISOISO  -0.3056   0.0 -0.3519 -0.2592   True
# -----------------------------------------------------
# ==========================================================================================
# =============================================Out-degree=============================================
# sum_CS_10D mean value: 11.0 SD value: 0.0
# sum_CsCh mean value: 11.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 11.0 SD value: 0.0
# sum_ISOISO mean value: 10.694444444444445 SD value: 1.8076910448359937
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh      0.0    1.0  -0.093   0.093  False
#  CS_10D Cs_5DIZ      0.0    1.0  -0.093   0.093  False
#  CS_10D  ISOISO  -0.3056 0.0001 -0.4876 -0.1235   True
#    CsCh Cs_5DIZ      0.0    1.0  -0.093   0.093  False
#    CsCh  ISOISO  -0.3056 0.0001 -0.4876 -0.1235   True
# Cs_5DIZ  ISOISO  -0.3056 0.0001 -0.4876 -0.1235   True
# ------------------------------------------------------
# ==========================================================================================
# =============================================Selectivity=============================================
# sum_CS_10D mean value: nan SD value: nan
# sum_CsCh mean value: nan SD value: nan
# sum_Cs_5DIZ mean value: nan SD value: nan
# sum_ISOISO mean value: nan SD value: nan
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
#  group1  group2 meandiff p-adj lower upper reject
# -------------------------------------------------
#  CS_10D    CsCh      nan   nan   nan   nan  False
#  CS_10D Cs_5DIZ      nan   nan   nan   nan  False
#  CS_10D  ISOISO      nan   nan   nan   nan  False
#    CsCh Cs_5DIZ      nan   nan   nan   nan  False
#    CsCh  ISOISO      nan   nan   nan   nan  False
# Cs_5DIZ  ISOISO      nan   nan   nan   nan  False
# -------------------------------------------------
# ==========================================================================================
# =============================================Betweenness centrality w=None=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_ISOISO mean value: 0.0 SD value: 0.0
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
#  group1  group2 meandiff p-adj lower upper reject
# -------------------------------------------------
#  CS_10D    CsCh      0.0   nan   0.0   0.0  False
#  CS_10D Cs_5DIZ      0.0   nan   0.0   0.0  False
#  CS_10D  ISOISO      0.0   nan   0.0   0.0  False
#    CsCh Cs_5DIZ      0.0   nan   0.0   0.0  False
#    CsCh  ISOISO      0.0   nan   0.0   0.0  False
# Cs_5DIZ  ISOISO      0.0   nan   0.0   0.0  False
# -------------------------------------------------
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# =============================================Betweenness centrality w=count=============================================
# sum_CS_10D mean value: 0.027307449494949468 SD value: 0.05614871794887839
# sum_CsCh mean value: 0.009646464646464622 SD value: 0.019193181776650775
# sum_Cs_5DIZ mean value: 0.014119318181818158 SD value: 0.0426549873024915
# sum_ISOISO mean value: 0.023863636363636347 SD value: 0.06583830228484198
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh  -0.0177 0.0001 -0.0279 -0.0074   True
#  CS_10D Cs_5DIZ  -0.0132 0.0055 -0.0235 -0.0029   True
#  CS_10D  ISOISO  -0.0034 0.9714 -0.0236  0.0167  False
#    CsCh Cs_5DIZ   0.0045 0.6769 -0.0058  0.0148  False
#    CsCh  ISOISO   0.0142  0.265 -0.0059  0.0343  False
# Cs_5DIZ  ISOISO   0.0097 0.5972 -0.0104  0.0299  False
# ------------------------------------------------------
# ==========================================================================================
# =============================================Betweenness centrality w=duration(seconds)=============================================
# sum_CS_10D mean value: 0.038920454545454494 SD value: 0.060738299741108746
# sum_CsCh mean value: 0.01630681818181814 SD value: 0.029803885066927827
# sum_Cs_5DIZ mean value: 0.022253787878787845 SD value: 0.041886879336889046
# sum_ISOISO mean value: 0.03585858585858584 SD value: 0.0748412597557004
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh  -0.0226    0.0 -0.0339 -0.0114   True
#  CS_10D Cs_5DIZ  -0.0167 0.0008 -0.0279 -0.0054   True
#  CS_10D  ISOISO  -0.0031 0.9843 -0.0251   0.019  False
#    CsCh Cs_5DIZ   0.0059 0.5239 -0.0053  0.0172  False
#    CsCh  ISOISO   0.0196 0.1021 -0.0025  0.0416  False
# Cs_5DIZ  ISOISO   0.0136 0.3843 -0.0084  0.0356  False
# ------------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=None=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_ISOISO mean value: 0.9847222222222223 SD value: 0.0230321165996903
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
#  group1  group2 meandiff p-adj  lower  upper  reject
# ----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0012 0.0012  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0012 0.0012  False
#  CS_10D  ISOISO  -0.0153   0.0 -0.0176 -0.013   True
#    CsCh Cs_5DIZ      0.0   1.0 -0.0012 0.0012  False
#    CsCh  ISOISO  -0.0153   0.0 -0.0176 -0.013   True
# Cs_5DIZ  ISOISO  -0.0153   0.0 -0.0176 -0.013   True
# ----------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=count=============================================
# sum_CS_10D mean value: 0.46229989419501555 SD value: 0.09643158210040705
# sum_CsCh mean value: 0.5510949948515844 SD value: 0.06154560213363579
# sum_Cs_5DIZ mean value: 0.5211000342187012 SD value: 0.06534846804453895
# sum_ISOISO mean value: 0.4875521814453408 SD value: 0.08734947734878958
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh   0.0888    0.0  0.0707  0.1069   True
#  CS_10D Cs_5DIZ   0.0588    0.0  0.0407  0.0769   True
#  CS_10D  ISOISO   0.0253  0.256 -0.0101  0.0606  False
#    CsCh Cs_5DIZ    -0.03 0.0001 -0.0481 -0.0119   True
#    CsCh  ISOISO  -0.0635    0.0 -0.0989 -0.0282   True
# Cs_5DIZ  ISOISO  -0.0335 0.0701 -0.0689  0.0018  False
# ------------------------------------------------------
# ==========================================================================================
# =============================================Clustering coefficient w=duration(seconds)=============================================
# sum_CS_10D mean value: 0.2953592312905061 SD value: 0.11632286938822338
# sum_CsCh mean value: 0.46524282232764896 SD value: 0.08127880027934264
# sum_Cs_5DIZ mean value: 0.43543937535388866 SD value: 0.08336429132443983
# sum_ISOISO mean value: 0.43306932270802023 SD value: 0.09839138369080148
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  CS_10D    CsCh   0.1699    0.0  0.1475  0.1923   True
#  CS_10D Cs_5DIZ   0.1401    0.0  0.1176  0.1625   True
#  CS_10D  ISOISO   0.1377    0.0  0.0938  0.1816   True
#    CsCh Cs_5DIZ  -0.0298 0.0037 -0.0522 -0.0074   True
#    CsCh  ISOISO  -0.0322 0.2348 -0.0761  0.0117  False
# Cs_5DIZ  ISOISO  -0.0024  0.999 -0.0463  0.0415  False
# ------------------------------------------------------
# ==========================================================================================
# =============================================PageRank centrality=============================================
# sum_CS_10D mean value: 0.08333333333333329 SD value: 1.3877787807814457e-17
# sum_CsCh mean value: 0.08333333333333329 SD value: 1.3877787807814457e-17
# sum_Cs_5DIZ mean value: 0.08333333333333329 SD value: 1.3877787807814457e-17
# sum_ISOISO mean value: 0.08333333333333331 SD value: 0.0010209675810975286
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
#  group1  group2 meandiff p-adj  lower  upper  reject
# ----------------------------------------------------
#  CS_10D    CsCh      0.0   1.0 -0.0001 0.0001  False
#  CS_10D Cs_5DIZ      0.0   1.0 -0.0001 0.0001  False
#  CS_10D  ISOISO      0.0   1.0 -0.0001 0.0001  False
#    CsCh Cs_5DIZ      0.0   1.0 -0.0001 0.0001  False
#    CsCh  ISOISO      0.0   1.0 -0.0001 0.0001  False
# Cs_5DIZ  ISOISO      0.0   1.0 -0.0001 0.0001  False
# ----------------------------------------------------
# ==========================================================================================
