# %%
import os
import toml
import scipy

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from src import settings
from src.utils import fileio

CONFIG_PATH = os.path.join(settings.CONFIG_DIR, 'main.toml')
with open(CONFIG_PATH, 'r') as file:
    config = toml.load(file)  

TREATMENTS = config['TREATMENTS']

INPUT_PATH = os.path.join(settings.RESULTS_DIR, 'global_measures')
all_treatments = fileio.load_files_from_folder(INPUT_PATH)

dataframes = []
for treatment_name, treatment_path in all_treatments.items():
    treatment_name = treatment_name.replace('.csv', '')
    if treatment_name in config['TREATMENTS']:
        df = pd.read_csv(treatment_path, index_col=0)
        df['Treatment'] = treatment_name
        dataframes.append(df)

combined_data = pd.concat(dataframes)
combined_data_reset = combined_data.reset_index()

for measure_name in combined_data.columns.tolist():
    if measure_name == 'Treatment': continue
    
    treatment_sums = {}
    for treatment in TREATMENTS:
        treatment_sums[f'sum_{treatment}'] = combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]

    anova_result = scipy.stats.f_oneway(*treatment_sums.values())

    all_data = np.concatenate([*treatment_sums.values()])
    group_labels = []
    for treatment in TREATMENTS:
        group_labels.extend([treatment] * len(combined_data_reset[combined_data_reset['Treatment'] == treatment][measure_name]))

    tukey_results = pairwise_tukeyhsd(all_data, group_labels)

    print('=' * 45 + measure_name + '=' * 45)

    for treatment in treatment_sums.keys():
        print(f"{treatment} mean value: {np.mean(treatment_sums[treatment])} SD value: {np.std(treatment_sums[treatment])}")

    print(tukey_results)

    plt.figure(figsize=(6, 4))
    order = TREATMENTS
    sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', errorbar='sd', order=order)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
    print('='*90)

    sns.pointplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', errorbar='se', order=order)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
    print('='*90)
        
    sns.boxplot(data=combined_data_reset, x='Treatment', y=measure_name, dodge=False, hue='Treatment', order=order)
    plt.xlabel('Treatment')
    plt.xticks(rotation=45)
    plt.ylabel(measure_name)
    plt.title(f'Distribution of {measure_name}', fontsize=18)
    plt.legend('')
    plt.show() 
    print('='*90)
# Out:
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# =============================================Total nodes=============================================
# sum_CS_10D mean value: 12.0 SD value: 0.0
# sum_CsCh mean value: 12.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 12.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 12.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 12.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 12.0 SD value: 0.0
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      0.0   nan   0.0   0.0  False
#       CS_10D      Cs_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     LDA_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh      Cs_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     LDA_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     LDA_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# LDA_OCT_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# -----------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Total edges=============================================
# sum_CS_10D mean value: 132.0 SD value: 0.0
# sum_CsCh mean value: 132.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 132.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 132.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 132.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 131.05 SD value: 2.67348087705897
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.9842 0.9842  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -1.0171 1.0171  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.9749 0.9749  False
#       CS_10D LDA_OCT_5DIZ    -0.95 0.0816 -1.9671 0.0671  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -1.0301 1.0301  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.9707 0.9707  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.9264 0.9264  False
#         CsCh LDA_OCT_5DIZ    -0.95 0.0588 -1.9207 0.0207  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.9842 0.9842  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.9612 0.9612  False
#      Cs_5DIZ LDA_OCT_5DIZ    -0.95 0.0748  -1.954  0.054  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -1.0171 1.0171  False
#     LDA_5DIZ LDA_OCT_5DIZ    -0.95 0.0547 -1.9112 0.0112  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.9749 0.9749  False
# LDA_OCT_5DIZ     OCT_5DIZ     0.95 0.0816 -0.0671 1.9671  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average degree weight=count=============================================
# sum_CS_10D mean value: 387.2368421052632 SD value: 91.07634988379999
# sum_CsCh mean value: 481.6884057971014 SD value: 76.98304764055891
# sum_Cs_5DIZ mean value: 424.3833333333333 SD value: 48.53850418882816
# sum_LDA_5DIZ mean value: 460.1319444444444 SD value: 83.6878013806244
# sum_OCT_5DIZ mean value: 474.3771929824561 SD value: 62.260367325362544
# sum_LDA_OCT_5DIZ mean value: 549.3833333333334 SD value: 129.98508568293516
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#    group1       group2    meandiff p-adj    lower    upper   reject
# -------------------------------------------------------------------
#       CS_10D         CsCh  94.4516 0.0094   15.4619 173.4412   True
#       CS_10D      Cs_5DIZ  37.1465 0.7744  -44.4792 118.7721  False
#       CS_10D     LDA_5DIZ  72.8951  0.083   -5.3465 151.1367  False
#       CS_10D LDA_OCT_5DIZ 162.1465    0.0   80.5208 243.7721   True
#       CS_10D     OCT_5DIZ  87.1404 0.0325    4.4749 169.8059   True
#         CsCh      Cs_5DIZ -57.3051 0.2788 -135.2058  20.5956  False
#         CsCh     LDA_5DIZ -21.5565 0.9594  -95.9038  52.7909  False
#         CsCh LDA_OCT_5DIZ  67.6949 0.1274  -10.2058 145.5956  False
#         CsCh     OCT_5DIZ  -7.3112 0.9998  -86.3008  71.6784  False
#      Cs_5DIZ     LDA_5DIZ  35.7486 0.7608  -41.3936 112.8908  False
#      Cs_5DIZ LDA_OCT_5DIZ    125.0 0.0002   44.4276 205.5724   True
#      Cs_5DIZ     OCT_5DIZ  49.9939 0.4863  -31.6318 131.6195  False
#     LDA_5DIZ LDA_OCT_5DIZ  89.2514 0.0135   12.1092 166.3936   True
#     LDA_5DIZ     OCT_5DIZ  14.2452  0.995  -63.9964  92.4869  False
# LDA_OCT_5DIZ     OCT_5DIZ -75.0061 0.0909 -156.6318   6.6195  False
# -------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average degree weight=duration(seconds)=============================================
# sum_CS_10D mean value: 751.9396929824562 SD value: 211.93467434652183
# sum_CsCh mean value: 556.8762077294685 SD value: 113.42069244611899
# sum_Cs_5DIZ mean value: 569.2222222222222 SD value: 162.88645356332347
# sum_LDA_5DIZ mean value: 565.6909722222222 SD value: 135.6416429625788
# sum_OCT_5DIZ mean value: 739.9480994152046 SD value: 370.6114062821286
# sum_LDA_OCT_5DIZ mean value: 780.9184027777778 SD value: 207.3792379918772
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================
#    group1       group2     meandiff p-adj    lower    upper   reject
# --------------------------------------------------------------------
#       CS_10D         CsCh -195.0635 0.0492 -389.7207  -0.4063   True
#       CS_10D      Cs_5DIZ -182.7175 0.0978 -383.8707  18.4358  False
#       CS_10D     LDA_5DIZ -186.2487 0.0647 -379.0626   6.5652  False
#       CS_10D LDA_OCT_5DIZ   28.9787 0.9983 -172.1745 230.1319  False
#       CS_10D     OCT_5DIZ  -11.9916    1.0 -215.7074 191.7242  False
#         CsCh      Cs_5DIZ    12.346    1.0 -179.6277 204.3198  False
#         CsCh     LDA_5DIZ    8.8148    1.0 -174.4023 192.0318  False
#         CsCh LDA_OCT_5DIZ  224.0422 0.0123   32.0685 416.0159   True
#         CsCh     OCT_5DIZ  183.0719  0.078  -11.5853 377.7291  False
#      Cs_5DIZ     LDA_5DIZ   -3.5312    1.0 -193.6357 186.5732  False
#      Cs_5DIZ LDA_OCT_5DIZ  211.6962 0.0295   13.1386 410.2538   True
#      Cs_5DIZ     OCT_5DIZ  170.7259 0.1451  -30.4274 371.8791  False
#     LDA_5DIZ LDA_OCT_5DIZ  215.2274 0.0168    25.123 405.3319   True
#     LDA_5DIZ     OCT_5DIZ  174.2571 0.1009  -18.5568  367.071  False
# LDA_OCT_5DIZ     OCT_5DIZ  -40.9703 0.9915 -242.1235 160.1829  False
# --------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Degree heterogeneity=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.014507613598522684 SD value: 0.038158020917443344
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0  -0.014  0.014  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0145 0.0145  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0139 0.0139  False
#       CS_10D LDA_OCT_5DIZ   0.0145 0.0502    -0.0  0.029  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0147 0.0147  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0139 0.0139  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0132 0.0132  False
#         CsCh LDA_OCT_5DIZ   0.0145 0.0344  0.0007 0.0284   True
#         CsCh     OCT_5DIZ      0.0    1.0  -0.014  0.014  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0137 0.0137  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0145 0.0454  0.0002 0.0288   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0145 0.0145  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0145 0.0316  0.0008 0.0282   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0139 0.0139  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0145 0.0502  -0.029    0.0  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Degree aassortativity=============================================
# sum_CS_10D mean value: nan SD value: nan
# sum_CsCh mean value: nan SD value: nan
# sum_Cs_5DIZ mean value: nan SD value: nan
# sum_LDA_5DIZ mean value: nan SD value: nan
# sum_OCT_5DIZ mean value: nan SD value: nan
# sum_LDA_OCT_5DIZ mean value: -0.163718708827411 SD value: 0.0409914361001085
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      nan   nan   nan   nan  False
#       CS_10D      Cs_5DIZ      nan   nan   nan   nan  False
#       CS_10D     LDA_5DIZ      nan   nan   nan   nan  False
#       CS_10D LDA_OCT_5DIZ      nan   nan   nan   nan  False
#       CS_10D     OCT_5DIZ      nan   nan   nan   nan  False
#         CsCh      Cs_5DIZ      nan   nan   nan   nan  False
#         CsCh     LDA_5DIZ      nan   nan   nan   nan  False
#         CsCh LDA_OCT_5DIZ      nan   nan   nan   nan  False
#         CsCh     OCT_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ     LDA_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ LDA_OCT_5DIZ      nan   nan   nan   nan  False
#      Cs_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
#     LDA_5DIZ LDA_OCT_5DIZ      nan   nan   nan   nan  False
#     LDA_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
# LDA_OCT_5DIZ     OCT_5DIZ      nan   nan   nan   nan  False
# -----------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Reciprocity=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.993891663891664 SD value: 0.020008581200458526
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0074 0.0074  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0076 0.0076  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0073 0.0073  False
#       CS_10D LDA_OCT_5DIZ  -0.0061 0.1925 -0.0137 0.0015  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0077 0.0077  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0073 0.0073  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0069 0.0069  False
#         CsCh LDA_OCT_5DIZ  -0.0061 0.1525 -0.0134 0.0012  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0074 0.0074  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0072 0.0072  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0061 0.1809 -0.0136 0.0014  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0076 0.0076  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0061 0.1448 -0.0133 0.0011  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0073 0.0073  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0061 0.1925 -0.0015 0.0137  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Network density=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9928030303030303 SD value: 0.020253643008022505
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0075 0.0075  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0077 0.0077  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0074 0.0074  False
#       CS_10D LDA_OCT_5DIZ  -0.0072 0.0816 -0.0149 0.0005  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0078 0.0078  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0074 0.0074  False
#         CsCh     LDA_5DIZ      0.0    1.0  -0.007  0.007  False
#         CsCh LDA_OCT_5DIZ  -0.0072 0.0588 -0.0146 0.0002  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0075 0.0075  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0073 0.0073  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0072 0.0748 -0.0148 0.0004  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0077 0.0077  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0072 0.0547 -0.0145 0.0001  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0074 0.0074  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0072 0.0816 -0.0005 0.0149  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Global efficiency=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9992424242424243 SD value: 0.003302196169349016
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0012 0.0012  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0013 0.0013  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0012 0.0012  False
#       CS_10D LDA_OCT_5DIZ  -0.0008  0.504  -0.002 0.0005  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0013 0.0013  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0012 0.0012  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0011 0.0011  False
#         CsCh LDA_OCT_5DIZ  -0.0008 0.4505  -0.002 0.0004  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0012 0.0012  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0012 0.0012  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0008 0.4892  -0.002 0.0005  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0013 0.0013  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0008 0.4392 -0.0019 0.0004  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0012 0.0012  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0008  0.504 -0.0005  0.002  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Transitivity=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.9927637675731192 SD value: 0.02116168745527837
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0078 0.0078  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0081 0.0081  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0077 0.0077  False
#       CS_10D LDA_OCT_5DIZ  -0.0072 0.1044 -0.0153 0.0008  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0082 0.0082  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0077 0.0077  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0073 0.0073  False
#         CsCh LDA_OCT_5DIZ  -0.0072 0.0772 -0.0149 0.0004  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0078 0.0078  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0076 0.0076  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0072 0.0963 -0.0152 0.0007  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0081 0.0081  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0072 0.0722 -0.0148 0.0004  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0077 0.0077  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0072 0.1044 -0.0008 0.0153  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Number of connected components=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 1.0 SD value: 0.0
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      0.0   nan   0.0   0.0  False
#       CS_10D      Cs_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     LDA_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh      Cs_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     LDA_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     LDA_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# LDA_OCT_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# -----------------------------------------------------------
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient unweighted=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.995185606060606 SD value: 0.012532773267005505
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0046  0.0046  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0048  0.0048  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0046  0.0046  False
#       CS_10D LDA_OCT_5DIZ  -0.0048 0.0464 -0.0096    -0.0   True
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0048  0.0048  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0046  0.0046  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0043  0.0043  False
#         CsCh LDA_OCT_5DIZ  -0.0048 0.0315 -0.0094 -0.0003   True
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0046  0.0046  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0045  0.0045  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0048 0.0418 -0.0095 -0.0001   True
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0048  0.0048  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0048 0.0289 -0.0093 -0.0003   True
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0046  0.0046  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0048 0.0464     0.0  0.0096   True
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient weight=count=============================================
# sum_CS_10D mean value: 0.46905737708882617 SD value: 0.08629020024970051
# sum_CsCh mean value: 0.5557638704452256 SD value: 0.05470821559906106
# sum_Cs_5DIZ mean value: 0.5211000342187013 SD value: 0.05367763740799122
# sum_LDA_5DIZ mean value: 0.5162641030767694 SD value: 0.0651173228747064
# sum_OCT_5DIZ mean value: 0.5113642513278072 SD value: 0.04847739491011162
# sum_LDA_OCT_5DIZ mean value: 0.4888224790712502 SD value: 0.07105547362972875
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh   0.0867 0.0006  0.0276  0.1458   True
#       CS_10D      Cs_5DIZ    0.052  0.142  -0.009  0.1131  False
#       CS_10D     LDA_5DIZ   0.0472 0.1881 -0.0113  0.1057  False
#       CS_10D LDA_OCT_5DIZ   0.0198 0.9359 -0.0413  0.0808  False
#       CS_10D     OCT_5DIZ   0.0423 0.3591 -0.0195  0.1042  False
#         CsCh      Cs_5DIZ  -0.0347 0.5196 -0.0929  0.0236  False
#         CsCh     LDA_5DIZ  -0.0395  0.317 -0.0951  0.0161  False
#         CsCh LDA_OCT_5DIZ  -0.0669 0.0145 -0.1252 -0.0087   True
#         CsCh     OCT_5DIZ  -0.0444 0.2566 -0.1035  0.0147  False
#      Cs_5DIZ     LDA_5DIZ  -0.0048 0.9999 -0.0625  0.0529  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0323 0.6321 -0.0926   0.028  False
#      Cs_5DIZ     OCT_5DIZ  -0.0097 0.9973 -0.0708  0.0513  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0274 0.7405 -0.0852  0.0303  False
#     LDA_5DIZ     OCT_5DIZ  -0.0049 0.9999 -0.0634  0.0536  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0225 0.8926 -0.0385  0.0836  False
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average clustering coefficient weight=duration(seconds)=============================================
# sum_CS_10D mean value: 0.2977817350424967 SD value: 0.11547309291665026
# sum_CsCh mean value: 0.4634823793770365 SD value: 0.0814512896793223
# sum_Cs_5DIZ mean value: 0.43543937535388866 SD value: 0.07394220504043164
# sum_LDA_5DIZ mean value: 0.4167514364598393 SD value: 0.08521154873837189
# sum_OCT_5DIZ mean value: 0.37902360181940675 SD value: 0.09126229833089904
# sum_LDA_OCT_5DIZ mean value: 0.3593494132098921 SD value: 0.11262355306003724
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh   0.1657    0.0  0.0793  0.2521   True
#       CS_10D      Cs_5DIZ   0.1377 0.0003  0.0484  0.2269   True
#       CS_10D     LDA_5DIZ    0.119 0.0014  0.0334  0.2045   True
#       CS_10D LDA_OCT_5DIZ   0.0616 0.3499 -0.0277  0.1508  False
#       CS_10D     OCT_5DIZ   0.0812 0.1046 -0.0092  0.1717  False
#         CsCh      Cs_5DIZ   -0.028 0.9315 -0.1132  0.0572  False
#         CsCh     LDA_5DIZ  -0.0467 0.5578 -0.1281  0.0346  False
#         CsCh LDA_OCT_5DIZ  -0.1041 0.0074 -0.1893 -0.0189   True
#         CsCh     OCT_5DIZ  -0.0845 0.0593 -0.1709  0.0019  False
#      Cs_5DIZ     LDA_5DIZ  -0.0187 0.9876 -0.1031  0.0657  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0761 0.1321 -0.1642   0.012  False
#      Cs_5DIZ     OCT_5DIZ  -0.0564 0.4504 -0.1457  0.0329  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0574 0.3653 -0.1418   0.027  False
#     LDA_5DIZ     OCT_5DIZ  -0.0377 0.7969 -0.1233  0.0479  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0197 0.9879 -0.0696   0.109  False
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality unweighted=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.0003030303030303 SD value: 0.0010276257550189698
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0004 0.0004  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0004 0.0004  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0004 0.0004  False
#       CS_10D LDA_OCT_5DIZ   0.0003 0.2253 -0.0001 0.0007  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0004 0.0004  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0004 0.0004  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0004 0.0004  False
#         CsCh LDA_OCT_5DIZ   0.0003 0.1818 -0.0001 0.0007  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0004 0.0004  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0004 0.0004  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0003 0.2127 -0.0001 0.0007  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0004 0.0004  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0003 0.1732 -0.0001 0.0007  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0004 0.0004  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0003 0.2253 -0.0007 0.0001  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality weight=count=============================================
# sum_CS_10D mean value: 0.028977272727272678 SD value: 0.018589707734667796
# sum_CsCh mean value: 0.009464207290294197 SD value: 0.006168015768637731
# sum_Cs_5DIZ mean value: 0.01411931818181813 SD value: 0.01049080737505689
# sum_LDA_5DIZ mean value: 0.012052819865319822 SD value: 0.009496733232405291
# sum_OCT_5DIZ mean value: 0.01578282828282822 SD value: 0.010193538855112606
# sum_LDA_OCT_5DIZ mean value: 0.025864898989898955 SD value: 0.023988346407760933
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh  -0.0195 0.0005 -0.0326 -0.0064   True
#       CS_10D      Cs_5DIZ  -0.0149 0.0225 -0.0284 -0.0013   True
#       CS_10D     LDA_5DIZ  -0.0169 0.0033 -0.0299  -0.004   True
#       CS_10D LDA_OCT_5DIZ  -0.0031 0.9852 -0.0166  0.0104  False
#       CS_10D     OCT_5DIZ  -0.0132 0.0661 -0.0269  0.0005  False
#         CsCh      Cs_5DIZ   0.0047 0.9018 -0.0083  0.0176  False
#         CsCh     LDA_5DIZ   0.0026 0.9902 -0.0097  0.0149  False
#         CsCh LDA_OCT_5DIZ   0.0164 0.0046  0.0035  0.0293   True
#         CsCh     OCT_5DIZ   0.0063 0.7281 -0.0068  0.0194  False
#      Cs_5DIZ     LDA_5DIZ  -0.0021 0.9971 -0.0149  0.0107  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0117 0.1188 -0.0016  0.0251  False
#      Cs_5DIZ     OCT_5DIZ   0.0017 0.9992 -0.0119  0.0152  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0138 0.0262   0.001  0.0266   True
#     LDA_5DIZ     OCT_5DIZ   0.0037 0.9607 -0.0092  0.0167  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0101  0.265 -0.0236  0.0034  False
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average betweenness centrality weight=duration(seconds)=============================================
# sum_CS_10D mean value: 0.04021132376395529 SD value: 0.020230424626260294
# sum_CsCh mean value: 0.01609025032938072 SD value: 0.008011099516305636
# sum_Cs_5DIZ mean value: 0.022253787878787838 SD value: 0.009467329249452506
# sum_LDA_5DIZ mean value: 0.01904987373737369 SD value: 0.009603523546495109
# sum_OCT_5DIZ mean value: 0.02416267942583728 SD value: 0.009064770826096602
# sum_LDA_OCT_5DIZ mean value: 0.03380681818181812 SD value: 0.02767611893156022
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh  -0.0241    0.0 -0.0384 -0.0098   True
#       CS_10D      Cs_5DIZ   -0.018 0.0078 -0.0327 -0.0032   True
#       CS_10D     LDA_5DIZ  -0.0212 0.0004 -0.0353  -0.007   True
#       CS_10D LDA_OCT_5DIZ  -0.0064 0.8079 -0.0212  0.0084  False
#       CS_10D     OCT_5DIZ   -0.016 0.0278  -0.031 -0.0011   True
#         CsCh      Cs_5DIZ   0.0062 0.8024 -0.0079  0.0203  False
#         CsCh     LDA_5DIZ    0.003 0.9879 -0.0105  0.0164  False
#         CsCh LDA_OCT_5DIZ   0.0177 0.0053  0.0036  0.0318   True
#         CsCh     OCT_5DIZ   0.0081 0.5764 -0.0062  0.0224  False
#      Cs_5DIZ     LDA_5DIZ  -0.0032 0.9854 -0.0172  0.0108  False
#      Cs_5DIZ LDA_OCT_5DIZ   0.0116  0.204  -0.003  0.0261  False
#      Cs_5DIZ     OCT_5DIZ   0.0019  0.999 -0.0129  0.0167  False
#     LDA_5DIZ LDA_OCT_5DIZ   0.0148 0.0317  0.0008  0.0287   True
#     LDA_5DIZ     OCT_5DIZ   0.0051 0.9012  -0.009  0.0193  False
# LDA_OCT_5DIZ     OCT_5DIZ  -0.0096 0.4124 -0.0244  0.0051  False
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality unweighted=============================================
# sum_CS_10D mean value: 1.0 SD value: 0.0
# sum_CsCh mean value: 1.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 1.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 1.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.993204365079365 SD value: 0.01963502679825921
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh      0.0    1.0 -0.0072 0.0072  False
#       CS_10D      Cs_5DIZ      0.0    1.0 -0.0075 0.0075  False
#       CS_10D     LDA_5DIZ      0.0    1.0 -0.0072 0.0072  False
#       CS_10D LDA_OCT_5DIZ  -0.0068 0.0969 -0.0143 0.0007  False
#       CS_10D     OCT_5DIZ      0.0    1.0 -0.0076 0.0076  False
#         CsCh      Cs_5DIZ      0.0    1.0 -0.0071 0.0071  False
#         CsCh     LDA_5DIZ      0.0    1.0 -0.0068 0.0068  False
#         CsCh LDA_OCT_5DIZ  -0.0068 0.0711 -0.0139 0.0003  False
#         CsCh     OCT_5DIZ      0.0    1.0 -0.0072 0.0072  False
#      Cs_5DIZ     LDA_5DIZ      0.0    1.0 -0.0071 0.0071  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0068 0.0891 -0.0142 0.0006  False
#      Cs_5DIZ     OCT_5DIZ      0.0    1.0 -0.0075 0.0075  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0068 0.0663 -0.0139 0.0003  False
#     LDA_5DIZ     OCT_5DIZ      0.0    1.0 -0.0072 0.0072  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0068 0.0969 -0.0007 0.0143  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality weight=count=============================================
# sum_CS_10D mean value: 0.06898073368998663 SD value: 0.0212236086057403
# sum_CsCh mean value: 0.048262206123648614 SD value: 0.008849721606277396
# sum_Cs_5DIZ mean value: 0.05474269075680921 SD value: 0.005950450334338696
# sum_LDA_5DIZ mean value: 0.05142047472328939 SD value: 0.009379412907781545
# sum_OCT_5DIZ mean value: 0.04963995462300406 SD value: 0.006264932786660937
# sum_LDA_OCT_5DIZ mean value: 0.049635299457238394 SD value: 0.018939488567617912
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#       CS_10D         CsCh  -0.0207    0.0 -0.0327 -0.0088   True
#       CS_10D      Cs_5DIZ  -0.0142  0.014 -0.0266 -0.0019   True
#       CS_10D     LDA_5DIZ  -0.0176 0.0005 -0.0294 -0.0057   True
#       CS_10D LDA_OCT_5DIZ  -0.0193 0.0002 -0.0317  -0.007   True
#       CS_10D     OCT_5DIZ  -0.0193 0.0002 -0.0319 -0.0068   True
#         CsCh      Cs_5DIZ   0.0065 0.6055 -0.0053  0.0183  False
#         CsCh     LDA_5DIZ   0.0032 0.9647 -0.0081  0.0144  False
#         CsCh LDA_OCT_5DIZ   0.0014 0.9994 -0.0104  0.0132  False
#         CsCh     OCT_5DIZ   0.0014 0.9994 -0.0106  0.0133  False
#      Cs_5DIZ     LDA_5DIZ  -0.0033 0.9625  -0.015  0.0084  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0051 0.8298 -0.0173  0.0071  False
#      Cs_5DIZ     OCT_5DIZ  -0.0051 0.8379 -0.0175  0.0073  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0018 0.9978 -0.0135  0.0099  False
#     LDA_5DIZ     OCT_5DIZ  -0.0018  0.998 -0.0136  0.0101  False
# LDA_OCT_5DIZ     OCT_5DIZ      0.0    1.0 -0.0124  0.0124  False
# ----------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Average closseness centrality weight=duration(seconds)=============================================
# sum_CS_10D mean value: 0.042101435849567645 SD value: 0.010342317467542364
# sum_CsCh mean value: 0.04371410562797744 SD value: 0.00964992231695821
# sum_Cs_5DIZ mean value: 0.04435685565020324 SD value: 0.00862147018176553
# sum_LDA_5DIZ mean value: 0.04414798546331553 SD value: 0.009727875205472924
# sum_OCT_5DIZ mean value: 0.038232687650108996 SD value: 0.012330735265260658
# sum_LDA_OCT_5DIZ mean value: 0.03653622897302282 SD value: 0.00982962113325017
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#       CS_10D         CsCh   0.0016  0.996 -0.0077 0.0109  False
#       CS_10D      Cs_5DIZ   0.0023 0.9838 -0.0074 0.0119  False
#       CS_10D     LDA_5DIZ    0.002 0.9874 -0.0072 0.0113  False
#       CS_10D LDA_OCT_5DIZ  -0.0056 0.5489 -0.0152  0.004  False
#       CS_10D     OCT_5DIZ  -0.0039 0.8584 -0.0136 0.0059  False
#         CsCh      Cs_5DIZ   0.0006    1.0 -0.0085 0.0098  False
#         CsCh     LDA_5DIZ   0.0004    1.0 -0.0083 0.0092  False
#         CsCh LDA_OCT_5DIZ  -0.0072 0.2156 -0.0163  0.002  False
#         CsCh     OCT_5DIZ  -0.0055 0.5293 -0.0148 0.0038  False
#      Cs_5DIZ     LDA_5DIZ  -0.0002    1.0 -0.0093 0.0089  False
#      Cs_5DIZ LDA_OCT_5DIZ  -0.0078 0.1685 -0.0173 0.0017  False
#      Cs_5DIZ     OCT_5DIZ  -0.0061 0.4402 -0.0157 0.0035  False
#     LDA_5DIZ LDA_OCT_5DIZ  -0.0076 0.1549 -0.0167 0.0015  False
#     LDA_5DIZ     OCT_5DIZ  -0.0059 0.4314 -0.0151 0.0033  False
# LDA_OCT_5DIZ     OCT_5DIZ   0.0017 0.9956 -0.0079 0.0113  False
# ---------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Newman modularity unweighted=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.0 SD value: 0.0
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      0.0   nan   0.0   0.0  False
#       CS_10D      Cs_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     LDA_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh      Cs_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     LDA_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     LDA_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# LDA_OCT_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# -----------------------------------------------------------
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Newman_modularity weight=count=============================================
# sum_CS_10D mean value: 0.0 SD value: 0.0
# sum_CsCh mean value: 0.0 SD value: 0.0
# sum_Cs_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_5DIZ mean value: 0.0 SD value: 0.0
# sum_OCT_5DIZ mean value: 0.0 SD value: 0.0
# sum_LDA_OCT_5DIZ mean value: 0.0 SD value: 0.0
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#    group1       group2    meandiff p-adj lower upper reject
# -----------------------------------------------------------
#       CS_10D         CsCh      0.0   nan   0.0   0.0  False
#       CS_10D      Cs_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     LDA_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#       CS_10D     OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh      Cs_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     LDA_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#         CsCh     OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     LDA_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#      Cs_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0   nan   0.0   0.0  False
#     LDA_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# LDA_OCT_5DIZ     OCT_5DIZ      0.0   nan   0.0   0.0  False
# -----------------------------------------------------------
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/milky/drosophila-SNA/.env/lib/python3.8/site-packages/statsmodels/sandbox/stats/multicomp.py:1300: RuntimeWarning: invalid value encountered in divide
#   st_range = np.abs(meandiffs) / std_pairs #studentized range statistic
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# =============================================Newman_modularity weight=dration(seconds)=============================================
# sum_CS_10D mean value: -5.843279076974507e-18 SD value: 2.4555680751285767e-16
# sum_CsCh mean value: 1.2550347234893073e-16 SD value: 2.783835163412496e-16
# sum_Cs_5DIZ mean value: 1.3877787807814457e-16 SD value: 3.473330558936429e-16
# sum_LDA_5DIZ mean value: -4.625929269271485e-18 SD value: 3.2759288201299133e-16
# sum_OCT_5DIZ mean value: -9.349246523159212e-17 SD value: 3.4410911230021673e-16
# sum_LDA_OCT_5DIZ mean value: 2.7755575615628907e-17 SD value: 3.843921764726602e-16
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#    group1       group2    meandiff p-adj  lower upper reject
# ------------------------------------------------------------
#       CS_10D         CsCh      0.0 0.7975  -0.0   0.0  False
#       CS_10D      Cs_5DIZ      0.0 0.7509  -0.0   0.0  False
#       CS_10D     LDA_5DIZ      0.0    1.0  -0.0   0.0  False
#       CS_10D LDA_OCT_5DIZ      0.0 0.9996  -0.0   0.0  False
#       CS_10D     OCT_5DIZ     -0.0 0.9645  -0.0   0.0  False
#         CsCh      Cs_5DIZ      0.0    1.0  -0.0   0.0  False
#         CsCh     LDA_5DIZ     -0.0 0.7604  -0.0   0.0  False
#         CsCh LDA_OCT_5DIZ     -0.0 0.9287  -0.0   0.0  False
#         CsCh     OCT_5DIZ     -0.0 0.2805  -0.0   0.0  False
#      Cs_5DIZ     LDA_5DIZ     -0.0  0.711  -0.0   0.0  False
#      Cs_5DIZ LDA_OCT_5DIZ     -0.0 0.8971  -0.0   0.0  False
#      Cs_5DIZ     OCT_5DIZ     -0.0 0.2533  -0.0   0.0  False
#     LDA_5DIZ LDA_OCT_5DIZ      0.0 0.9995  -0.0   0.0  False
#     LDA_5DIZ     OCT_5DIZ     -0.0 0.9526  -0.0   0.0  False
# LDA_OCT_5DIZ     OCT_5DIZ     -0.0 0.8637  -0.0   0.0  False
# ------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
